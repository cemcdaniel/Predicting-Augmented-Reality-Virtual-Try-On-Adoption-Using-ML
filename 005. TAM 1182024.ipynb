# %% [markdown]
# # 5. Dissertation - AR VTO-Latest Version TAM

# %%
#print(sklearn.__version__)

# %%
#!pip freeze > requirements.txt

# %% [raw]
# 1.  Dissertation - AR VTO-Latest Version 09172024 Cleaned Dataset-Copy1
# 2.  Dissertation - AR VTO-Latest Version 09172024-Data Exploration-Copy1
# 3.  Dissertation - AR VTO-Latest Version 09172024- Create PCA Feature List
# 4.  Dissertation - AR VTO-Latest Version 09172024-BuildTestHarnesses-with extra models
# ##5.  Dissertation - AR VTO-Latest Version TAM
# 6.  Dissertation - AR VTO-Latest Version Gradient Boost
# 7.  Dissertation - AR VTO-Latest Version KNN
# 8.  Dissertation - AR VTO-Latest Version Lasso
# 9.  Dissertation - AR VTO-Latest Version MLP
# 10. Dissertation - AR VTO-Latest Version MLR
# 11. Dissertation - AR VTO-Latest Version RF
# 12. Dissertation - AR VTO-Latest Version Ridge
# 13. Dissertation - AR VTO-Latest Version SVR
# 13. Dissertation - AR VTO-Latest Version XGBoost
# 14. Dissertation - AR VTO - Stats Model MLR
# 15. Dissertation - AR VTO-Latest Version Final Model

# %% [markdown]
# ### Change Log

# %% [raw]
# 1. 10/23 Changed title to match purpose of notebook
# 2. 10/23 Change to read df_survey_cleaned from current directory
# 3. 10/23 added print('End of Script')
# 4. 11/1  Add Script to predict BI

# %%
import pandas as pd
import numpy as np
from numpy import arange
import scipy.stats as stats
from scipy.stats import spearmanr

from sklearn.preprocessing import StandardScaler

from sklearn.metrics import mean_squared_error, r2_score
# Load libraries
import numpy
from numpy import arange
from matplotlib import pyplot
from pandas import read_csv

from sklearn.metrics import mean_squared_error
from sklearn.datasets import make_regression
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import Lasso
from sklearn.metrics import mean_squared_error, r2_score
import statsmodels.api as sm
import semopy
from semopy import Model, Optimizer, calc_stats
#from pdpbox import pdp, get_dataset, info_plots
from sklearn.metrics import mutual_info_score
from sklearn import metrics
#import eli5
#from eli5.sklearn import PermutationImportance

# Statistical Analysis
import statsmodels.api as sm
from statsmodels.stats.outliers_influence import variance_inflation_factor
from scipy.stats import chi2_contingency
from factor_analyzer import FactorAnalyzer
import semopy
from semopy import Model, Optimizer, calc_stats

#Visualization
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib import pyplot
 

# Miscellaneous
# Set display options to show all columns
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)

# %%
#read csv file

df_survey_cleaned = pd.read_csv('df_survey_cleaned.csv')

# %%
#display column headers and the first row

df_survey_cleaned.head(2)
# Out:
#              Timestamp  AR_Knowledgeable  familiar_with_technology  \
# 0  13/10/2022 11:08:13               4.0                       3.0
# 1  13/10/2022 13:29:22               3.0                       3.0
#
#    use_AR_everyday        use_in_all_aspects  Virtual_shopping_environment  \
# 0              3.0  Du lịch ảo / trải nghiệm                           3.0
# 1              3.0                   Mua sắm                           3.0
#
#    Virtual_tour  Visualize_model  Emulation  PE1  PE2  PE3  PE4  SOI1  SOI2  \
# 0           3.0              3.0        3.0  4.0  4.0  4.0  4.0   3.0   3.0
# 1           3.0              3.0        3.0  3.0  3.0  3.0  3.0   3.0   3.0
#
#    SOI3  SOI4  SEI1  SEI2  SEI3  PEOU1  PEOU2  PEOU3  PU1  PU2  PU3  PU4   B1  \
# 0   3.0   3.0   3.0   3.0   3.0    4.0    4.0    4.0  4.0  3.0  3.0  3.0  3.0
# 1   3.0   3.0   3.0   3.0   3.0    3.0    3.0    3.0  3.0  3.0  3.0  3.0  3.0
#
# ...

# %%
#Get Size of dataset
df_survey_cleaned.shape
# Out:
# (424, 198)

# %% [markdown]
# # TAM

# %% [raw]
# Survey data validation process.
#
# 1. Exploratory Factor Analysis (EFA)
#    Rationale: Start with EFA to explore the underlying factor structure of your data, especially if this is a new or adapted measurement model for AR VTO acceptance.
#
# 2. Kaiser-Meyer-Olkin (KMO) test
#    Rationale: Conduct the KMO test alongside EFA to assess sampling adequacy and suitability of your data for factor analysis.
#
# 3. Cronbach's Alpha
#    Rationale: After identifying the factor structure, use Cronbach's Alpha to assess the internal consistency reliability of your scales.
#
# 4. Confirmatory Factor Analysis (CFA)
#    Rationale: Use CFA to confirm the factor structure identified in EFA and to further assess the measurement model.
#
# 5. Convergent and Discriminant Validity
#    Rationale: As part of CFA, assess convergent and discriminant validity to ensure your constructs are properly measured and distinct.
#
# 6. Fornell-Larcker criterion test
#    Rationale: This test is part of assessing discriminant validity, providing a specific method to ensure constructs are distinct.
#
# 7. Variance Inflation Factor (VIF)
#    Rationale: Conduct VIF analysis to check for multicollinearity among your predictor variables.
#
# 8. Harman's Single Factor Test
#    Rationale: Perform this test last to check for common method bias in your survey data.
#
# This order allows you to progressively build and validate your measurement model for AR VTO acceptance. Starting with exploratory techniques (EFA, KMO) helps you understand the underlying structure of your data. Then, moving to confirmatory techniques (CFA, convergent/discriminant validity) allows you to validate this structure. The reliability check (Cronbach's Alpha) ensures your scales are internally consistent. Finally, checks for multicollinearity (VIF) and common method bias (Harman's test) help ensure the quality of your data for subsequent analyses.
#
# After completing these steps, you'll have a well-validated measurement model for AR VTO acceptance, which you can then use in your semopy analysis. The results from this process will provide a solid foundation for comparison with your machine learning algorithms (MLR, SVR, KNN, RF, and MLP), allowing you to contrast the performance of traditional SEM approaches with various ML techniques in predicting behavioral intention towards AR VTO.

# %% [markdown]
# ## Validity

# %% [markdown]
# ### Harman's Test

# %%
import pandas as pd
from factor_analyzer import FactorAnalyzer


variables = ['PU', 'PEOU', 'PE', 'HM', 'AT', 'SOI', 'SEI', 'Gender_num', 'AGE_num']
df = df_survey_cleaned[variables]

# Drop missing values if any
df.dropna(inplace=True)

# Initialize factor analysis object and perform factor analysis using 1 factor
fa = FactorAnalyzer(n_factors=1, rotation=None)
fa.fit(df)

# Get the variance of each variable explained by the single factor
variances = fa.get_factor_variance()

# The total variance explained by the single factor
total_variance_explained = variances[1][0] * 100

print(f"Total variance explained by the single factor: {total_variance_explained:.2f}%")

# Check for common method bias
if total_variance_explained > 50:
    print("Common method bias is present, as more than 50% of the variance is explained by a single factor.")
else:
    print("Common method bias is not detected, as less than 50% of the variance is explained by a single factor.")
# Out:
# Total variance explained by the single factor: 59.33%
# Common method bias is present, as more than 50% of the variance is explained by a single factor.
# C:\Users\cemcd\AppData\Local\Temp\ipykernel_9440\3797877342.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.dropna(inplace=True)

# %% [markdown]
# ### VIF - to tesst for Multicollinearity amonst the constructs and within the construcst

# %%
import pandas as pd
import numpy as np
from statsmodels.stats.outliers_influence import variance_inflation_factor

# Define the variables for VIF analysis
variables_for_vif = [
    "BI1", "BI2", "BI3", "PU1", "PU2", "PU3", "PU4",
    "PEOU1", "PEOU2", "PEOU3",
    "PE1", "PE2", "PE3",
    "PPV1", "PPV2", "PPV3",
    "SEI1", "SEI2", "SEI3",
    "SOI1", "SOI2", "SOI3", "SOI4",
    "AT1", "AT2", "AT3",
    "HM1", "HM2", "HM3"
]

# Select the relevant subset of the DataFrame for VIF analysis
df_vif = df_survey_cleaned[variables_for_vif].copy()

# Calculate VIF for each feature
vif_data = pd.DataFrame()
vif_data['Feature'] = variables_for_vif
vif_data['VIF'] = [variance_inflation_factor(df_vif.values, i) for i in range(len(variables_for_vif))]

# Sort the dataframe by VIF values in descending order
vif_data = vif_data.sort_values('VIF', ascending=False)

# Display the VIF values
print(vif_data)

# Identify variables with high VIF (e.g., VIF > 5 or 10)
high_vif = vif_data[vif_data['VIF'] > 5]
print("\nVariables with high VIF (> 5):")
print(high_vif)
# Out:
#    Feature        VIF
# 26     HM1  71.646110
# 23     AT1  69.192631
# 4      PU2  68.327793
# 0      BI1  63.769230
# 13    PPV1  61.460294
# 27     HM2  56.321308
# 16    SEI1  55.884632
# 28     HM3  55.656466
# 25     AT3  55.622873
# 19    SOI1  55.582008
# 15    PPV3  54.608754
# 6      PU4  53.805170
# 3      PU1  52.515605
# 12     PE3  50.835203
# 1      BI2  49.851848
# 5      PU3  49.833931
# 2      BI3  49.202959
# 10     PE1  48.384749
# 24     AT2  47.192898
# 14    PPV2  46.168397
# 20    SOI2  45.766473
# 7    PEOU1  45.602201
# 8    PEOU2  45.174440
# 11     PE2  43.733384
# 21    SOI3  43.484314
# 9    PEOU3  43.354923
# 17    SEI2  42.398085
# 18    SEI3  40.858651
# 22    SOI4  35.347957
#
# Variables with high VIF (> 5):
#    Feature        VIF
# 26     HM1  71.646110
# 23     AT1  69.192631
# 4      PU2  68.327793
# 0      BI1  63.769230
# 13    PPV1  61.460294
# 27     HM2  56.321308
# 16    SEI1  55.884632
# 28     HM3  55.656466
# 25     AT3  55.622873
# ...

# %% [markdown]
# ### Calculate Fornall

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from factor_analyzer import FactorAnalyzer
from scipy.stats import pearsonr

# Step 1: Load and prepare your data
# Replace 'your_data.csv' with the path to your actual data file
df = df_survey_cleaned

# List of variables for each construct
constructs = {
    'BI': ['BI1', 'BI2', 'BI3'],
    'PU': ['PU1', 'PU2', 'PU3', 'PU4'],
    'PEOU': ['PEOU1', 'PEOU2', 'PEOU3'],
    'PE': ['PE1', 'PE2', 'PE3'],
    'PPV': ['PPV1', 'PPV2', 'PPV3'],
    'SEI': ['SEI1', 'SEI2', 'SEI3'],
    'SOI': ['SOI1', 'SOI2', 'SOI3', 'SOI4'],
    'AT': ['AT1', 'AT2', 'AT3'],
    'HM': ['HM1', 'HM2', 'HM3']
}

# Standardize the data
scaler = StandardScaler()
df_scaled = pd.DataFrame(scaler.fit_transform(df[sum(constructs.values(), [])]), 
                         columns=sum(constructs.values(), []))

# Step 2: Calculate factor loadings and AVE for each construct
factor_loadings = {}
ave_values = {}

for construct, items in constructs.items():
    # Perform factor analysis
    fa = FactorAnalyzer(rotation=None, n_factors=1)
    fa.fit(df_scaled[items])
    
    # Get factor loadings
    loadings = fa.loadings_
    factor_loadings[construct] = loadings.flatten()
    
    # Calculate AVE
    ave = np.mean(loadings**2)
    ave_values[construct] = ave

# Print factor loadings and AVE values
print("Factor Loadings:")
for construct, loadings in factor_loadings.items():
    print(f"{construct}: {loadings}")

print("\nAVE Values:")
for construct, ave in ave_values.items():
    print(f"{construct}: {ave:.4f}")

# Step 3: Calculate correlation matrix
correlation_matrix = pd.DataFrame(index=constructs.keys(), columns=constructs.keys())

for construct1 in constructs:
    for construct2 in constructs:
        if construct1 == construct2:
            correlation_matrix.loc[construct1, construct2] = 1.0
        else:
            # Calculate average correlation between items of the two constructs
            correlations = []
            for item1 in constructs[construct1]:
                for item2 in constructs[construct2]:
                    corr, _ = pearsonr(df_scaled[item1], df_scaled[item2])
                    correlations.append(corr)
            avg_corr = np.mean(correlations)
            correlation_matrix.loc[construct1, construct2] = avg_corr

print("\nCorrelation Matrix:")
print(correlation_matrix)

# Step 4: Perform Fornell-Larcker criterion test
def fornell_larcker_test(correlation_matrix, ave_values):
    results = {}
    for construct in correlation_matrix.columns:
        # Get correlations for this construct
        correlations = correlation_matrix[construct]
        # Get square root of AVE for this construct
        ave_sqrt = np.sqrt(ave_values[construct])
        # Check if square root of AVE is greater than correlations with other constructs
        validity_check = all(ave_sqrt > correlations[correlations.index != construct])
        results[construct] = validity_check
    return results

# Run the test
fl_results = fornell_larcker_test(correlation_matrix, ave_values)

# Print results
print("\nFornell-Larcker Criterion Test Results:")
for construct, result in fl_results.items():
    print(f"{construct}: {'Pass' if result else 'Fail'}")

# Create a comparison matrix
comparison_df = correlation_matrix.copy()
for construct in comparison_df.columns:
    comparison_df.loc[construct, construct] = np.sqrt(ave_values[construct])

print("\nComparison Matrix (diagonal shows sqrt(AVE)):")
comparison_df
# Out:
# Factor Loadings:
# BI: [-0.90005427 -0.82274156 -0.82423183]
# PU: [-0.81252369 -0.89099994 -0.81656855 -0.84397382]
# PEOU: [-0.87073523 -0.81822265 -0.82930762]
# PE: [-0.87576949 -0.84082171 -0.87300026]
# PPV: [-0.87259342 -0.76441926 -0.80196911]
# SEI: [-0.88566677 -0.82131411 -0.81487875]
# SOI: [-0.88310338 -0.78389845 -0.84695857 -0.79149459]
# AT: [-0.9039535  -0.82934835 -0.80962388]
# HM: [0.88600861 0.83941421 0.86726897]
#
# AVE Values:
# BI: 0.7221
# PU: 0.7083
# PEOU: 0.7051
# PE: 0.7454
# PPV: 0.6630
# SEI: 0.7077
# SOI: 0.6845
# AT: 0.7201
# HM: 0.7473
#
# Correlation Matrix:
#             BI        PU      PEOU        PE       PPV       SEI       SOI  \
# BI         1.0  0.646907  0.599704  0.593918  0.647837  0.610309  0.587627
# PU    0.646907       1.0  0.666165  0.567782  0.632443   0.61223  0.556559
# PEOU  0.599704  0.666165       1.0  0.572704  0.584002  0.609371  0.570682
# PE    0.593918  0.567782  0.572704       1.0  0.561538  0.599773  0.639127
# ...

# %% [raw]
# ### Calculate Fornell-Larcker criterion test
#
# The measurement model demonstrated strong psychometric properties across all constructs. Average Variance Extracted (AVE) values ranged from 0.6630 to 0.7473, exceeding the recommended threshold of 0.5 (Hair et al., 2019), indicating robust convergent validity. Perceived Enjoyment (PE; AVE = 0.7454) and Hedonic Motivation (HM; AVE = 0.7473) exhibited the highest AVE values, while Perceived Price Value (PPV; AVE = 0.6630) showed the lowest, albeit still well above the threshold. Factor loadings for all items were substantial, ranging from 0.76 to 0.90, surpassing the 0.7 criterion (Fornell & Larcker, 1981). Discriminant validity was established through the Fornell-Larcker criterion, with the square root of AVE for each construct exceeding its correlations with other constructs (Fornell & Larcker, 1981). The highest inter-construct correlation was observed between Behavioral Intention and Hedonic Motivation (r = 0.703), yet it did not violate discriminant validity criteria. All constructs passed the Fornell-Larcker test, further confirming discriminant validity. These results collectively indicate that the measurement model meets and exceeds established psychometric thresholds for convergent and discriminant validity, providing a solid foundation for subsequent structural analysis.
#
# References:
#
# Fornell, C., & Larcker, D. F. (1981). Evaluating structural equation models with unobservable variables and measurement error. Journal of Marketing Research, 18(1), 39-50.
#
# Hair, J. F., Black, W. C., Babin, B. J., & Anderson, R. E. (2019). Multivariate data analysis (8th ed.). Cengage Learning. test to assess the discriminant validity of the constructs.

# %% [raw]
# Let's evaluate these results in detail:
#
# 1. Factor Loadings:
#    - All factor loadings are above 0.7 (in absolute value), which is considered good.
#    - The loadings range from about 0.76 to 0.90, indicating strong relationships between items and their respective constructs.
#    - The negative signs for most loadings are not concerning; they just indicate the direction of the relationship.
#
# 2. AVE Values:
#    - All AVE values are above 0.5, which is the recommended threshold.
#    - They range from 0.6630 (PPV) to 0.7473 (HM), indicating good convergent validity.
#    - PE and HM have the highest AVE values, suggesting these constructs explain more of the variance in their indicators.
#
# 3. Correlation Matrix:
#    - Correlations between constructs range from moderate (around 0.55) to strong (around 0.70).
#    - The highest correlation is between BI and HM (0.703162), which might warrant further investigation.
#    - No correlations are extremely high (> 0.9), which is good for discriminant validity.
#
# 4. Fornell-Larcker Criterion Test:
#    - All constructs pass the Fornell-Larcker test, which is excellent.
#    - This indicates good discriminant validity between all constructs.
#
# 5. Comparison Matrix:
#    - The diagonal values (square root of AVE) are all higher than the off-diagonal values in their respective rows and columns.
#    - This visual representation confirms the passing of the Fornell-Larcker criterion for all constructs.
#
# Evaluation:
#
# 1. Convergent Validity:
#    - Strong factor loadings and high AVE values indicate good convergent validity for all constructs.
#    - All constructs meet the criteria for convergent validity (AVE > 0.5, factor loadings > 0.7).
#
# 2. Discriminant Validity:
#    - All constructs pass the Fornell-Larcker criterion, demonstrating good discriminant validity.
#    - The square root of AVE for each construct is greater than its correlation with other constructs.
#
# 3. Construct Reliability:
#    - While not explicitly calculated, the high factor loadings and AVE values suggest good construct reliability.
#
# 4. Potential Areas of Concern:
#    - The correlation between BI and HM (0.703162) is relatively high. While it doesn't violate discriminant validity, it might indicate some conceptual overlap between these constructs.
#    - PPV has the lowest AVE (0.6630), though it's still above the threshold. This construct might be slightly less well-defined than the others.
#
# 5. Overall Model Quality:
#    - The measurement model demonstrates good psychometric properties.
#    - Both convergent and discriminant validity are established for all constructs.
#
# Recommendations:
#
# 1. Consider examining the conceptual distinction between BI (Behavioral Intention) and HM (Hedonic Motivation) due to their high correlation.
# 2. While PPV (Perceived Price Value) passes all criteria, it might benefit from some refinement to improve its AVE.
# 3. Proceed with confidence in using these constructs in your structural model.
# 4. Consider additional validity tests (e.g., HTMT ratio) for further confirmation of discriminant validity.
# 5. When reporting results, highlight the strong psychometric properties of your measurement model.
#
# In conclusion, your measurement model demonstrates excellent validity and reliability. All constructs show good convergent and discriminant validity, providing a solid foundation for further analysis or structural modeling.

# %% [markdown]
# ### KMO Adequacy

# %%
from factor_analyzer.factor_analyzer import calculate_kmo


independent_vars = ['PU1', 'PU2', 'PU3','PU4','AT1', 'AT2', 'AT3', 'PEOU1', 'PEOU2', 'PEOU3',
                   'PPV1', 'PPV2', 'PPV3', 'HM1', 'HM2', 'HM3', 'SOI1', 'SOI2', 'SOI3','SOI4',
                   'SEI1', 'SEI2', 'SEI3', 'PE1', 'PE2', 'PE3','PE4']
dependent_var = 'BI'

# Calculate the KMO test
kmo_all, kmo_model = calculate_kmo(df_survey_cleaned[independent_vars])

# Print the KMO value
print(f"KMO Model Adequacy: {kmo_model:.4f}")
# Out:
# KMO Model Adequacy: 0.9788
# C:\Users\cemcd\anaconda3\Lib\site-packages\factor_analyzer\utils.py:244: UserWarning: The inverse of the variance-covariance matrix was calculated using the Moore-Penrose generalized matrix inversion, due to its determinant being at or very close to zero.
#   warnings.warn(

# %% [raw]
# Based on the Kaiser-Meyer-Olkin (KMO) test result of 0.9788, we can evaluate the model adequacy as follows:
#
# 1. Interpretation scale:
# According to Kaiser's classification:
# - 0.00 to 0.49: Unacceptable
# - 0.50 to 0.59: Miserable
# - 0.60 to 0.69: Mediocre
# - 0.70 to 0.79: Middling
# - 0.80 to 0.89: Meritorious
# - 0.90 to 1.00: Marvelous
#
# 2. Evaluation:
# The KMO value of 0.9788 falls in the highest category of "Marvelous" (0.90 to 1.00).
#
# 3. Interpretation:
# - This extremely high KMO value indicates that the sampling is more than adequate for factor analysis.
# - It suggests that there are strong partial correlations between variables relative to the sum of correlations.
# - The data is very well-suited for factor analysis, with a high proportion of variance among variables that might be common variance.
#
# 4. Implications:
# - The variables in my dataset are highly interrelated.
# - Factor analysis is likely to yield clear and reliable factors.
# - You can proceed with factor analysis with a high degree of confidence in the suitability of my data.
#
# 5. Comparison to thresholds:
# - This value is well above the minimum acceptable threshold of 0.6 mentioned in some sources.
# - It exceeds the more stringent threshold of 0.8 that some researchers consider as the minimum for a "good" factor analysis.
#
# 6. Caution:
# - While this is an excellent KMO value, it's important to consider other aspects of my data and research context when interpreting results.
# - Extremely high values (close to 1) might sometimes indicate redundancy in variables, so it's worth examining my variables for potential multicollinearity.
#
# In conclusion, a KMO value of 0.9788 indicates exceptional sampling adequacy and suggests that my data is extremely well-suited for factor analysis. You can proceed with high confidence in the appropriateness of factor analysis for my dataset.
#
# Citations:
# [1] https://www.statisticshowto.com/kaiser-meyer-olkin/
# [2] https://en.wikipedia.org/wiki/Kaiser%E2%80%93Meyer%E2%80%93Olkin_test
# [3] https://bookdown.org/luguben/EFA_in_R/kaiser-meyer-olkin-kmo.html
# [4] https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7446803/
# [5] https://www.analysisinn.com/post/kmo-and-bartlett-s-test-of-sphericity/
# [6] https://viewer.mathworks.com/?embed=web&url=https%3A%2F%2Fwww.mathworks.com%2Fmatlabcentral%2Fmlc-downloads%2Fdownloads%2Fsubmissions%2F12736%2Fversions%2F1%2Fcontents%2Fkmo.m&viewer=plain_code
# [7] https://www.researchgate.net/post/What-should-be-ideal-KMO-value-for-factor-analysis

# %%
import pandas as pd
from factor_analyzer.factor_analyzer import calculate_kmo


# Extract the independent variables
independent_vars = ['PU1', 'PU2', 'PU3','PU4','AT1', 'AT2', 'AT3', 'PEOU1', 'PEOU2', 'PEOU3',
                   'PPV1', 'PPV2', 'PPV3', 'HM1', 'HM2', 'HM3', 'SOI1', 'SOI2', 'SOI3','SOI4',
                   'SEI1', 'SEI2', 'SEI3', 'PE1', 'PE2', 'PE3','PE4']
dependent_var = 'BI'

X = df_survey_cleaned[independent_vars]

# Perform the KMO test
kmo_all, kmo_model = calculate_kmo(X)

# Print the overall KMO value
print(f"Overall KMO: {kmo_model:.4f}")

# Print the KMO values for each independent variable
for col in X.columns:
    kmo_value = X[col].corr(X[col])
    print(f"KMO for {col}: {kmo_value:.4f}")
# Out:
# Overall KMO: 0.9788
# KMO for PU1: 1.0000
# KMO for PU2: 1.0000
# KMO for PU3: 1.0000
# KMO for PU4: 1.0000
# KMO for AT1: 1.0000
# KMO for AT2: 1.0000
# KMO for AT3: 1.0000
# KMO for PEOU1: 1.0000
# KMO for PEOU2: 1.0000
# KMO for PEOU3: 1.0000
# KMO for PPV1: 1.0000
# KMO for PPV2: 1.0000
# KMO for PPV3: 1.0000
# KMO for HM1: 1.0000
# KMO for HM2: 1.0000
# KMO for HM3: 1.0000
# KMO for SOI1: 1.0000
# KMO for SOI2: 1.0000
# KMO for SOI3: 1.0000
# KMO for SOI4: 1.0000
# KMO for SEI1: 1.0000
# KMO for SEI2: 1.0000
# KMO for SEI3: 1.0000
# KMO for PE1: 1.0000
# KMO for PE2: 1.0000
# KMO for PE3: 1.0000
# KMO for PE4: 1.0000
# C:\Users\cemcd\anaconda3\Lib\site-packages\factor_analyzer\utils.py:244: UserWarning: The inverse of the variance-covariance matrix was calculated using the Moore-Penrose generalized matrix inversion, due to its determinant being at or very close to zero.
#   warnings.warn(

# %%
 
#df = df_survey[variables]

import pandas as pd
from factor_analyzer import FactorAnalyzer
from factor_analyzer.factor_analyzer import calculate_bartlett_sphericity, calculate_kmo

 
variables = ['PU1', 'PU2', 'PU3','PU4','AT1', 'AT2', 'AT3', 'PEOU1', 'PEOU2', 'PEOU3',
                   'PPV1', 'PPV2', 'PPV3', 'HM1', 'HM2', 'HM3', 'SOI1', 'SOI2', 'SOI3','SOI4',
                   'SEI1', 'SEI2', 'SEI3', 'PE1', 'PE2', 'PE3','PE4']
df = df_survey_cleaned[variables]

# Check the suitability of my data for factor analysis
chi_square_value, p_value = calculate_bartlett_sphericity(df)
kmo_all, kmo_model = calculate_kmo(df)

print(f"Bartlett's test chi-square value: {chi_square_value}, p-value: {p_value}")
print(f"KMO test: {kmo_model}")

# Perform EFA
fa = FactorAnalyzer(rotation=None, n_factors=7, method='minres')
fa.fit(df)

# Check Eigenvalues to decide the number of factors
ev, v = fa.get_eigenvalues()
print(f"Eigenvalues: {ev}")

# You might decide to rotate factors for better interpretability
fa = FactorAnalyzer(rotation='varimax', n_factors=7, method='minres')
fa.fit(df)
loadings = fa.loadings_
loadings_df = pd.DataFrame(loadings)

# Get the factor loadings
print("Factor Loadings:\n", pd.DataFrame(loadings, index=variables))

# Optionally, get the variance explained by each factor
variance = fa.get_factor_variance()
# Out:
# Bartlett's test chi-square value: 10994.345578956547, p-value: 0.0
# KMO test: 0.9787776526552086
# Eigenvalues: [17.09730972  1.37650634  0.89192076  0.83768344  0.5409698   0.4995804
#   0.42616358  0.41976206  0.38481747  0.38083618  0.35471642  0.34234865
#   0.31203775  0.30115581  0.29073825  0.28321718  0.26199068  0.25262612
#   0.23086104  0.22067317  0.21185386  0.20762442  0.19726608  0.18960938
#   0.17298394  0.16473247  0.15001503]
# Factor Loadings:
#                0         1         2         3         4         5         6
# PU1    0.442858  0.240594  0.266875  0.669239  0.049916  0.006296 -0.022503
# PU2    0.554236  0.278165  0.249825  0.500579  0.305477  0.030987 -0.004635
# PU3    0.606368  0.284949  0.214562  0.361167  0.267920 -0.026475  0.153691
# PU4    0.587258  0.313443  0.200115  0.446573  0.160716  0.006078  0.013547
# AT1    0.670408  0.321152  0.217191  0.322971  0.256336  0.123652 -0.081686
# ...

# %%
# Convert the DataFrame to a markdown table
markdown_table = loadings_df.to_markdown(index=False)

# Print or use the markdown table
print(markdown_table)
# Out:
# |        0 |        1 |        2 |        3 |           4 |           5 |           6 |
# |---------:|---------:|---------:|---------:|------------:|------------:|------------:|
# | 0.442858 | 0.240594 | 0.266875 | 0.669239 |  0.0499163  |  0.00629568 | -0.0225031  |
# | 0.554236 | 0.278165 | 0.249825 | 0.500579 |  0.305477   |  0.0309872  | -0.00463521 |
# | 0.606368 | 0.284949 | 0.214562 | 0.361167 |  0.26792    | -0.0264753  |  0.153691   |
# | 0.587258 | 0.313443 | 0.200115 | 0.446573 |  0.160716   |  0.00607816 |  0.0135471  |
# | 0.670408 | 0.321152 | 0.217191 | 0.322971 |  0.256336   |  0.123652   | -0.0816856  |
# | 0.657975 | 0.297298 | 0.215081 | 0.274338 |  0.0939037  |  0.241351   | -0.030628   |
# | 0.617668 | 0.30518  | 0.269692 | 0.334955 |  0.121644   |  0.0637515  |  0.0491322  |
# | 0.327879 | 0.320061 | 0.329741 | 0.643503 | -0.0504608  |  0.143066   |  0.0368029  |
# | 0.405718 | 0.285132 | 0.298509 | 0.579443 |  0.0832428  | -0.0264921  |  0.224405   |
# ...

# %% [raw]
# The results of the factor analysis provide valuable insights into the underlying structure of the data. Here's an evaluation of the key findings:
#
# 1. Sampling Adequacy and Sphericity:
#    The Kaiser-Meyer-Olkin (KMO) test value of 0.979 indicates excellent sampling adequacy, well above the recommended threshold of 0.6 (Kaiser, 1974). Bartlett's test of sphericity is significant (χ2 = 10994.35, p < .001), confirming that the correlation matrix is not an identity matrix and factor analysis is appropriate.
#
# 2. Eigenvalues and Factor Extraction:
#    The eigenvalues suggest that two factors have values greater than 1 (17.097 and 1.377). These two factors explain approximately 68.42% of the total variance. However, the scree plot (not provided) should be examined to confirm the number of factors to retain.
#
# 3. Factor Loadings:
#    The factor loading matrix reveals a complex structure with significant cross-loadings:
#
#    a) Factor 0 shows high loadings (>0.6) for several items across different constructs (AT1, AT2, AT3, PU3, PPV1, PPV3, HM1, HM2, HM3), suggesting a general factor.
#
#    b) Factor 1 has high loadings for PE items (PE1, PE2, PE3, PE4), indicating a distinct Performance Expectancy factor.
#
#    c) Factor 2 shows high loadings for SOI and SEI items, suggesting a Social Influence factor.
#
#    d) Factor 3 has high loadings for PU and PEOU items, potentially representing a combined Perceived Usefulness and Ease of Use factor.
#
# 4. Cross-loadings:
#    Many items load significantly (>0.3) on multiple factors, indicating a lack of simple structure and potential issues with discriminant validity between constructs.
#
# 5. Interpretation:
#    The factor structure suggests that while there are distinct factors representing some of the theoretical constructs (e.g., PE, SOI/SEI), there is also significant overlap between constructs, particularly in Factor 0.
#
# Recommendations:
# 1. Consider using oblique rotation methods (e.g., Promax) to account for the correlated factors.
# 2. Examine the theoretical basis for the observed factor structure, particularly the general factor (Factor 0).
# 3. Assess the discriminant validity of the constructs given the high cross-loadings.
# 4. Consider item reduction or refinement to achieve a cleaner factor structure.
# 5. Validate the factor structure with confirmatory factor analysis (CFA) on a separate sample.
#
# In conclusion, while the data shows good suitability for factor analysis, the complex loading pattern suggests that the underlying structure may not align perfectly with the hypothesized construct distinctions. Further analysis and potential refinement of the measurement model may be necessary.
#
# Reference:
# Kaiser, H. F. (1974). An index of factorial simplicity. Psychometrika, 39(1), 31-36.

# %% [markdown]
# ### Cronbach's Alpha

# %%
import pandas as pd
from pingouin import cronbach_alpha

# Define constructs
constructs = {
    'PU': ['PU1', 'PU2', 'PU3','PU4'],
    'AT': ['AT1', 'AT2', 'AT3'],
    'PEU': ['PEOU1', 'PEOU2', 'PEOU3'],
    'PPV': ['PPV1', 'PPV2', 'PPV3'],
    'HM': ['HM1', 'HM2', 'HM3'],
    'SOI': ['SOI1', 'SOI2', 'SOI3','SOI4'],
    'SEI': ['SEI1', 'SEI2', 'SEI3'],
    'PE': ['PE1', 'PE2', 'PE3','PE4']
}

# Calculate Cronbach's alpha for each construct
for construct, variables in constructs.items():
    construct_data = df_survey_cleaned[variables]
    alpha = cronbach_alpha(construct_data)
    print(f"Cronbach's alpha for {construct}: {alpha}")
# Out:
# Cronbach's alpha for PU: (0.9054292595424759, array([0.89 , 0.919]))
# Cronbach's alpha for AT: (0.8835933597202476, array([0.863, 0.902]))
# Cronbach's alpha for PEU: (0.8773070383038567, array([0.856, 0.896]))
# Cronbach's alpha for PPV: (0.8526684581044442, array([0.827, 0.875]))
# Cronbach's alpha for HM: (0.8978540190527856, array([0.88 , 0.914]))
# Cronbach's alpha for SOI: (0.8954501139847528, array([0.878, 0.911]))
# Cronbach's alpha for SEI: (0.8775892033766053, array([0.856, 0.896]))
# Cronbach's alpha for PE: (0.9240634129575526, array([0.912, 0.935]))

# %% [raw]
# The Cronbach's alpha values provided for each construct offer valuable insights into the internal consistency reliability of the measurement scales. Here's an evaluation of the results:
#
# 1. Perceived Usefulness (PU): α = 0.905 (95% CI: 0.890 - 0.919)
#    Interpretation: Excellent internal consistency.
#
# 2. Attitude (AT): α = 0.884 (95% CI: 0.863 - 0.902)
#    Interpretation: Good to excellent internal consistency.
#
# 3. Perceived Ease of Use (PEU): α = 0.877 (95% CI: 0.856 - 0.896)
#    Interpretation: Good internal consistency.
#
# 4. Perceived Price Value (PPV): α = 0.853 (95% CI: 0.827 - 0.875)
#    Interpretation: Good internal consistency.
#
# 5. Hedonic Motivation (HM): α = 0.898 (95% CI: 0.880 - 0.914)
#    Interpretation: Good to excellent internal consistency.
#
# 6. Social Influence (SOI): α = 0.895 (95% CI: 0.878 - 0.911)
#    Interpretation: Good to excellent internal consistency.
#
# 7. Self-Efficacy (SEI): α = 0.878 (95% CI: 0.856 - 0.896)
#    Interpretation: Good internal consistency.
#
# 8. Performance Expectancy (PE): α = 0.924 (95% CI: 0.912 - 0.935)
#    Interpretation: Excellent internal consistency.
#
# Overall Evaluation:
# 1. All constructs demonstrate good to excellent internal consistency reliability, with Cronbach's alpha values ranging from 0.853 to 0.924.
#
# 2. Performance Expectancy (PE) shows the highest reliability (α = 0.924), indicating very strong internal consistency among its items.
#
# 3. Perceived Price Value (PPV) has the lowest reliability (α = 0.853), but it still falls within the "good" range of internal consistency.
#
# 4. The narrow confidence intervals for each alpha value suggest precision in the reliability estimates.
#
# 5. None of the constructs fall below the commonly accepted threshold of 0.7, indicating that all scales are reliable for research purposes (Nunnally & Bernstein, 1994).
#
# Implications and Recommendations:
# 1. The high reliability across all constructs suggests that the items within each scale are measuring the same underlying construct consistently.
#
# 2. The excellent reliability of PE and PU (α > 0.9) indicates that these scales are particularly well-suited for individual assessment or high-stakes decision-making.
#
# 3. While all scales show good reliability, there might be room for minor refinement in the PPV scale to potentially improve its internal consistency.
#
# 4. The high reliability values, particularly for PE and PU, should be considered in light of potential redundancy among items. Very high alphas (> 0.95) can sometimes indicate item redundancy (Streiner, 2003).
#
# 5. These reliability results, combined with the factor analysis findings, provide a strong foundation for the measurement model. However, it's important to also assess validity (convergent and discriminant) to ensure a comprehensive evaluation of the measurement scales.
#
# In conclusion, the Cronbach's alpha results indicate that all constructs in the study demonstrate strong internal consistency reliability, supporting their use in further analyses and theoretical model testing.
#
# References:
# Nunnally, J. C., & Bernstein, I. H. (1994). Psychometric theory (3rd ed.). McGraw-Hill.
# Streiner, D. L. (2003). Starting at the beginning: An introduction to coefficient alpha and internal consistency. Journal of Personality Assessment, 80(1), 99-103.

# %% [markdown]
# ### Exploratory Factor Analysis

# %%
import pandas as pd
import numpy as np
from factor_analyzer import FactorAnalyzer
from factor_analyzer.factor_analyzer import calculate_kmo, calculate_bartlett_sphericity
import pingouin as pg


# Extract the independent variables
X = df_survey_cleaned[['PU1', 'PU2', 'PU3','PU4', 'AT1', 'AT2', 'AT3', 'PEOU1', 'PEOU2', 'PEOU3', 'PPV1', 'PPV2', 'PPV3', 
               'HM1', 'HM2', 'HM3', 'SOI1', 'SOI2', 'SOI3','SOI4', 'SEI1', 'SEI2', 'SEI3', 'PE1', 'PE2', 'PE3','PE4']]

# Perform EFA
fa = FactorAnalyzer(n_factors=3, rotation="varimax")
fa.fit(X)
loadings = fa.loadings_

# Calculate Cronbach's alpha for each factor
print("Reliability Analysis:")
for i in range(3):
    factor_items = [X.columns[j] for j, loading in enumerate(loadings[:, i]) if abs(loading) > 0.4]
    factor_data = X[factor_items]
    alpha_value = pg.cronbach_alpha(factor_data)
    print(f"Factor {i+1} Cronbach's Alpha:", alpha_value)
# Out:
# Reliability Analysis:
# Factor 1 Cronbach's Alpha: (0.965986098565747, array([0.961, 0.971]))
# Factor 2 Cronbach's Alpha: (0.9624211805149268, array([0.957, 0.967]))
# Factor 3 Cronbach's Alpha: (0.9411595844133621, array([0.932, 0.949]))

# %% [raw]
# This evaluation focuses on the reliability analysis of three factors identified through factor analysis. Cronbach's alpha was calculated for each factor to assess their internal consistency reliability. Here's an interpretation of the results:
#
# Factor 1 Cronbach's Alpha: 0.966 (95% CI: 0.961 - 0.971)
# Interpretation: Excellent internal consistency
#
# Factor 2 Cronbach's Alpha: 0.962 (95% CI: 0.957 - 0.967)
# Interpretation: Excellent internal consistency
#
# Factor 3 Cronbach's Alpha: 0.941 (95% CI: 0.932 - 0.949)
# Interpretation: Excellent internal consistency
#
# Overall Evaluation:
#
# 1. All three factors demonstrate exceptionally high internal consistency reliability, with Cronbach's alpha values well above the commonly accepted threshold of 0.7 (Nunnally & Bernstein, 1994).
#
# 2. The alpha values for all factors exceed 0.9, which is considered excellent reliability (DeVellis, 2016).
#
# 3. The narrow confidence intervals for each alpha value suggest high precision in the reliability estimates.
#
# 4. Factor 1 shows the highest reliability (α = 0.966), closely followed by Factor 2 (α = 0.962) and Factor 3 (α = 0.941).
#
# Implications and Considerations:
#
# 1. High Reliability: The extremely high alpha values indicate that the items within each factor are very strongly interrelated and are measuring the same underlying construct with a high degree of consistency.
#
# 2. Potential Redundancy: While high reliability is generally desirable, alpha values above 0.95 may suggest potential item redundancy (Streiner, 2003). This is particularly relevant for Factors 1 and 2.
#
# 3. Scale Length: The very high alpha values might also be influenced by a large number of items in each factor. Cronbach's alpha tends to increase with the number of items (Cortina, 1993).
#
# 4. Unidimensionality: These high alpha values support the unidimensionality of each factor, which is a crucial assumption in many statistical analyses.
#
# 5. Practical Implications: Scales with such high reliability are well-suited for individual assessment or high-stakes decision-making scenarios.
#
# Recommendations:
#
# 1. Item Analysis: Conduct an item-level analysis to identify any potentially redundant items within each factor, especially for Factors 1 and 2.
#
# 2. Factor Structure Review: Revisit the factor analysis results to ensure that the high reliability is not due to overfactoring or the inclusion of highly similar items.
#
# 3. Validity Assessment: While reliability is high, it's crucial to also assess the validity of these factors to ensure they are measuring distinct constructs as intended.
#
# 4. Scale Refinement: Consider the possibility of shortening the scales, particularly for Factors 1 and 2, without significantly reducing reliability. This could improve the efficiency of the measurement instrument.
#
# 5. Theoretical Alignment: Ensure that the items grouped in each factor align well with theoretical expectations for the constructs they are intended to measure.
#
# In conclusion, while the reliability analysis indicates exceptionally strong internal consistency for all three factors, the very high alpha values warrant careful consideration of potential item redundancy and the need for scale refinement. These highly reliable factors provide a strong foundation for further analysis, but should be balanced with considerations of validity and practical utility in the research context.
#
# References:
#
# Cortina, J. M. (1993). What is coefficient alpha? An examination of theory and applications. Journal of Applied Psychology, 78(1), 98-104.
#
# DeVellis, R. F. (2016). Scale development: Theory and applications (4th ed.). Sage Publications.
#
# Nunnally, J. C., & Bernstein, I. H. (1994). Psychometric theory (3rd ed.). McGraw-Hill.
#
# Streiner, D. L. (2003). Starting at the beginning: An introduction to coefficient alpha and internal consistency. Journal of Personality Assessment, 80(1), 99-103.

# %% [markdown]
# ### Construct Validity -  Convergent and Discriminant Validity

# %%
import pandas as pd
from factor_analyzer import FactorAnalyzer
from scipy.stats import pearsonr


# Extract the independent variables
X = df_survey_cleaned [['PU1', 'PU2', 'PU3','PU4','AT1', 'AT2', 'AT3', 'PEOU1', 'PEOU2', 'PEOU3','PPV1',
                        'PPV2', 'PPV3', 'HM1', 'HM2', 'HM3', 'SOI1', 'SOI2', 'SOI3', 'SEI1', 'SEI2', 'SEI3', 'PE1', 'PE2', 'PE3','PE4']]

# Perform exploratory factor analysis
fa = FactorAnalyzer(n_factors=7, rotation="varimax")
fa.fit(X)
loadings = fa.loadings_

# Calculate factor scores
factor_scores = fa.transform(X)

# Assess convergent validity
print("Convergent Validity:")
for i in range(7):
    factor_name = f"Factor {i+1}"
    print(f"{factor_name}:")
    for j, variable in enumerate(X.columns):
        corr, p_value = pearsonr(factor_scores[:, i], X[variable])
        print(f"{variable}: r = {corr:.4f}, p = {p_value:.4f}")
    print()

# Assess discriminant validity
print("Discriminant Validity:")
for i in range(7):
    factor_name = f"Factor {i+1}"
    print(f"{factor_name}:")
    for j in range(7):
        if i != j:
            other_factor_name = f"Factor {j+1}"
            corr, p_value = pearsonr(factor_scores[:, i], factor_scores[:, j])
            print(f"{factor_name} vs {other_factor_name}: r = {corr:.4f}, p = {p_value:.4f}")
    print()
# Out:
# Convergent Validity:
# Factor 1:
# PU1: r = 0.4451, p = 0.0000
# PU2: r = 0.5358, p = 0.0000
# PU3: r = 0.6046, p = 0.0000
# PU4: r = 0.5974, p = 0.0000
# AT1: r = 0.6734, p = 0.0000
# AT2: r = 0.6611, p = 0.0000
# AT3: r = 0.6326, p = 0.0000
# PEOU1: r = 0.3299, p = 0.0000
# PEOU2: r = 0.4003, p = 0.0000
# PEOU3: r = 0.3512, p = 0.0000
# PPV1: r = 0.6433, p = 0.0000
# PPV2: r = 0.5960, p = 0.0000
# PPV3: r = 0.7182, p = 0.0000
# HM1: r = 0.7937, p = 0.0000
# HM2: r = 0.7824, p = 0.0000
# HM3: r = 0.7595, p = 0.0000
# SOI1: r = 0.3272, p = 0.0000
# SOI2: r = 0.4135, p = 0.0000
# SOI3: r = 0.3810, p = 0.0000
# SEI1: r = 0.3883, p = 0.0000
# SEI2: r = 0.3480, p = 0.0000
# SEI3: r = 0.4008, p = 0.0000
# PE1: r = 0.3151, p = 0.0000
# PE2: r = 0.3329, p = 0.0000
# PE3: r = 0.3355, p = 0.0000
# PE4: r = 0.3542, p = 0.0000
#
# Factor 2:
# PU1: r = 0.2890, p = 0.0000
# PU2: r = 0.3207, p = 0.0000
# PU3: r = 0.3159, p = 0.0000
# PU4: r = 0.3545, p = 0.0000
# AT1: r = 0.3635, p = 0.0000
# ...

# %% [raw]
# The purpose of convergent and discriminant validity is to assess the construct validity of a measurement model. Let's discuss each and apply them to the given results:
#
# Convergent Validity:
#
# Purpose: Convergent validity assesses whether items that are supposed to measure the same construct are indeed related. It indicates the extent to which different measures of the same construct converge or share a high proportion of variance.
#
# Application to Results:
# 1. Factor 1 shows strong convergent validity for HM (Hedonic Motivation) items (r > 0.75) and moderate to strong for PU (Perceived Usefulness), AT (Attitude), and PPV (Perceived Price Value) items (r > 0.5).
#
# 2. Factor 2 demonstrates excellent convergent validity for PE (Perceived Enjoyment) items (r > 0.78) and moderate for SOI (Social Influence) items (r > 0.55).
#
# 3. Factor 3 shows strong convergent validity for PEOU (Perceived Ease of Use) items (r > 0.68) and PU1 (r = 0.7861).
#
# 4. Factor 4 exhibits strong convergent validity for SEI (Self-Efficacy) items (r > 0.63) and moderate for SOI items (r > 0.51).
#
# 5. Factors 5, 6, and 7 show weak convergent validity, with most items loading below 0.5.
#
# Discriminant Validity:
#
# Purpose: Discriminant validity assesses the extent to which constructs that are supposed to be unrelated are indeed not related. It ensures that measures of different constructs are distinguishable from each other.
#
# Application to Results:
# 1. The correlations between factors are generally low (r < 0.2), which is good for discriminant validity.
#
# 2. Most inter-factor correlations are not statistically significant (p > 0.05), further supporting discriminant validity.
#
# 3. The highest correlation is between Factor 2 and Factor 4 (r = 0.1209, p = 0.0127), but it's still relatively low, indicating good discriminant validity.
#
# Overall Interpretation:
#
# 1. The first four factors show good convergent validity for specific constructs:
#    - Factor 1: HM, with some overlap from PU, AT, and PPV
#    - Factor 2: PE and SOI
#    - Factor 3: PEOU and some PU
#    - Factor 4: SEI and some SOI
#
# 2. There's excellent discriminant validity between these factors, indicating that they are measuring distinct constructs.
#
# 3. Factors 5, 6, and 7 show poor convergent validity and may not represent meaningful constructs.
#
# 4. Some constructs (e.g., SOI) load on multiple factors, suggesting they might be multidimensional or need refinement.
#
# 5. The strong discriminant validity between factors suggests that a 4-factor solution might be more appropriate, as the last three factors don't show clear patterns and don't correlate strongly with other factors.
#
# Recommendations:
# 1. Consider a 4-factor solution, focusing on the constructs that show strong convergent validity.
# 2. Re-examine items that cross-load on multiple factors (e.g., SOI items) to ensure they're properly capturing the intended construct.
# 3. Review the theoretical basis for the constructs that don't emerge clearly (those loading primarily on Factors 5-7) and consider revising or removing these items.
# 4. Conduct a confirmatory factor analysis (CFA) based on the 4-factor structure suggested by these results to further validate the measurement model.

# %%
# Set pandas display options to show all rows and columns
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', None)

# %% [markdown]
# ## Confirmatory Factory Analysis (CFA)

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler

X = df_survey_cleaned

# Create a StandardScaler object
scaler = StandardScaler()

# List of variables to standardize (exclude the target variable if you have one)
variables_to_standardize = [
    "BI1", "BI2", "BI3", "PU1", "PU2", "PU3", "PU4", 
    "PEOU1", "PEOU2", "PEOU3", "PE1", "PE2", "PE3", 
    "PPV1", "PPV2", "PPV3", "SEI1", "SEI2", "SEI3", 
    "SOI1", "SOI2", "SOI3", "SOI4", "AT1", "AT2", "AT3", 
    "HM1", "HM2", "HM3", "AGE_num", "Gender_num"
]

# Standardize the selected variables
X_standardized = X.copy()
X_standardized[variables_to_standardize] = scaler.fit_transform(X[variables_to_standardize])

# Print the first few rows of the standardized data to verify
#print(X_standardized.head())

# check the mean and standard deviation of the standardized variables
#print("\nMean of standardized variables:")
#print(X_standardized[variables_to_standardize].mean())
#print("\nStandard deviation of standardized variables:")
#print(X_standardized[variables_to_standardize].std())

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from semopy import Model
from semopy.stats import calc_stats

# Step 1: Data Preparation
scaler = StandardScaler()

variables_to_standardize = [
    "BI1", "BI2", "BI3", "PU1", "PU2", "PU3", "PU4", 
    "PEOU1", "PEOU2", "PEOU3", 
    "PPV1", "PPV2", "PPV3",
    "SEI1", "SEI2", "SEI3", 
    "SOI1", "SOI2", "SOI3", "SOI4",
    "AT1", "AT2", "AT3", 
    "HM1", "HM2", "HM3", "AGE_num", "Gender_num"
]
X = df_survey_cleaned[variables_to_standardize]

# Standardize the selected variables
X_standardized = pd.DataFrame(scaler.fit_transform(X), columns=X.columns)

# Step 2: Define the model
model = """

# Measurement model
PU =~ PU1 + PU2 + PU3 + PU4
PEOU =~ PEOU1 + PEOU2 + PEOU3
BI =~ BI1 + BI2 + BI3
PPV =~ PPV1 + PPV2 + PPV3
SOI =~ SOI1 + SOI2 + SOI3 + SOI4
SEI =~ SEI1 + SEI2 + SEI3
HM =~ HM1 + HM2 + HM3

"""

# Step 3: Fit the model
sem_model = Model(model)
results = sem_model.fit(X_standardized)

# Step 4: Calculate and print fit indices
stats = calc_stats(sem_model)

stats
# Out:
#        DoF  DoF Baseline        chi2  chi2 p-value  chi2 Baseline       CFI  \
# Value  209           253  439.464082           0.0    9285.461348  0.974485
#
#             GFI      AGFI       NFI       TLI     RMSEA         AIC  \
# Value  0.952672  0.942708  0.952672  0.969113  0.051057  131.927056
#
#               BIC    LogLik
# Value  403.259198  1.036472

# %% [raw]
# Confirmatory Factor Analysis (CFA) evaluation:
#
# 1. Degrees of Freedom (DoF): 379
#    - This indicates the number of degrees of freedom in your model. It's the difference between the number of observations and the number of parameters estimated.
#
# 2. Chi-square (χ²): 738.100796
#    - p-value: 0.0
#    - The significant p-value (< 0.05) suggests that there is a discrepancy between the model-implied and observed covariance matrices. However, chi-square is sensitive to sample size and often significant in large samples.
#    - Interpretation: While significant, this alone doesn't necessarily indicate poor fit, especially with large samples.
#
# 3. Comparative Fit Index (CFI): 0.969823
#    - CFI > 0.95 indicates good fit. Your model meets this criterion, suggesting a good fit.
#    - Interpretation: The model fits well compared to a baseline model.
#
# 4. Goodness of Fit Index (GFI): 0.940307
#    - GFI > 0.90 is considered acceptable. Your model meets this criterion.
#    - Interpretation: The model explains the variance in the data well.
#
# 5. Adjusted Goodness of Fit Index (AGFI): 0.926762
#    - AGFI > 0.90 is considered good. Your model meets this criterion.
#    - Interpretation: The model fits well, even when adjusted for model complexity.
#
# 6. Normed Fit Index (NFI): 0.940307
#    - NFI > 0.90 is considered good. Your model meets this criterion.
#    - Interpretation: The model fits well compared to a null model.
#
# 7. Tucker-Lewis Index (TLI): 0.962976
#    - TLI > 0.95 indicates good fit. Your model meets this criterion.
#    - Interpretation: The model fits well, accounting for model complexity.
#
# 8. Root Mean Square Error of Approximation (RMSEA): 0.047328
#    - RMSEA < 0.05 indicates good fit, 0.05-0.08 is acceptable. Your model shows good fit according to this index.
#    - Interpretation: The model approximates the data well, with reasonable error of approximation.
#
# 9. Akaike Information Criterion (AIC): 230.518392
#    - Used for model comparison. Lower values indicate better fit when comparing models.
#
# 10. Bayesian Information Criterion (BIC): 704.337207
#     - Similar to AIC, used for model comparison with a stronger penalty for complexity.
#
# 11. Log-Likelihood: 1.740804
#     - Higher values indicate better fit.
#
# Overall Interpretation:
#
# 1. Model Fit: Your CFA model demonstrates good fit across multiple indices (CFI, GFI, AGFI, NFI, TLI, RMSEA). All of these meet or exceed typical cutoff criteria for good model fit in CFA.
#
# 2. Convergent Validity: The good fit indices suggest that your items are likely loading well on their intended factors, indicating good convergent validity.
#
# 3. Discriminant Validity: While these indices don't directly measure discriminant validity, the good overall fit suggests that your factors are likely distinct from each other.
#
# 4. Model Complexity: The AGFI and TLI, which penalize for model complexity, still indicate good fit, suggesting that your model is not overfitted.
#
# 5. Absolute vs. Comparative Fit: Both absolute (RMSEA, GFI) and comparative (CFI, TLI) fit indices show good fit, indicating that your model is both a good absolute fit to the data and a good fit relative to a baseline model.
#
# Recommendations:
#
# 1. Report multiple fit indices (e.g., CFI, TLI, RMSEA) when presenting your results.
# 2. Examine the specific factor loadings to ensure they are substantial and significant.
# 3. Check for any large modification indices that might suggest ways to improve the model, but only make changes if theoretically justifiable.
# 4. Consider testing alternative models if you have theoretical reasons to do so, and compare them using AIC and BIC.
#
# In conclusion, your CFA model demonstrates good fit according to commonly used criteria, suggesting that your hypothesized factor structure is a good representation of the relationships in your data. This provides strong support for the construct validity of your measures.

# %% [markdown]
# ## Create TAM Model

# %% [markdown]
# ### TAM model to explain BI using all constructs except PE - be sure to mention Davis, VAn heyden

# %%
pd.set_option('display.max_rows', 500)

# %%
import pandas as pd
import numpy as np
from semopy import Model, calc_stats
import matplotlib.pyplot as plt

# Define the model specification
model_spec = """
# Measurement model
PU =~ PU1 + PU2 + PU3 + PU4
PEOU =~ PE1 + PE2 + PE3
BI =~ BI1 + BI2 + BI3
PPV =~PPV1 + PPV2 + PPV3
SOI =~ SOI1+ SOI2 +SOI3 + SOI4
SEI =~ SEI1 + SEI2 + SEI3
HM =~ HM1 +HM2 + HM3
AT =~ AT1 + AT2 + AT3

# Structural model
PEOU ~  PPV + SOI + SEI + AGE_num + Gender_num
PU ~ HM + PPV + PEOU + SOI + SEI + AGE_num + Gender_num
HM ~ PEOU
BI ~ PU 
BI ~ PEOU
BI ~ HM
"""

# Create and fit the model
model = Model(model_spec)
res = model.fit(df_survey_cleaned)

# Get the parameter estimates
estimates = model.inspect()

# Find the variance of BI
bi_variance = estimates[estimates['lval'] == 'BI']['Estimate'].values[0]
print(f"Total variance of BI: {bi_variance}")

# Extract only path coefficients related to BI
bi_paths = estimates[(estimates['lval'] == 'BI') & (estimates['op'] == '~')]

print("Path Coefficients related to BI:")
print(bi_paths)

# Calculate and print fit statistics
fit_stats = calc_stats(model)
print("\nModel Fit Statistics:")
print(fit_stats)

# R-squared values for endogenous variables
r_squared = estimates[estimates['op'] == '~~'].copy()
r_squared['R_squared'] = 1 - pd.to_numeric(r_squared['Estimate'], errors='coerce')
r_squared = r_squared[r_squared['lval'] == r_squared['rval']]  # Only keep diagonal elements
r_squared = r_squared[['lval', 'R_squared']]
r_squared.columns = ['Variable', 'R_squared']

# Find the R-squared of BI
bi_r_squared = r_squared[r_squared['Variable'] == 'BI']['R_squared'].values

if len(bi_r_squared) > 0:
    bi_r_squared = bi_r_squared[0]
    # Create TAM_model_BI_R_squared dataframe
    TAM_model_BI_R_squared = pd.DataFrame({
        'model_name': ['TAM'],
        'BI_R_squared': [bi_r_squared],
        'run_type': ['Initial']
    })
    print("\nTAM_model_BI_R_squared:")
    print(TAM_model_BI_R_squared)
else:
    print("\nWarning: R-squared for BI not found in the DataFrame.")

# Create a list to store the important features
important_features = []

for _, row in bi_paths.iterrows():
    feature = {
        'from': row['rval'],
        'to': row['lval'],
        'Estimate': row['Estimate'],
        'Std_Err': row['Std. Err'],
        'z-value': row['z-value'],
        'p-value': row['p-value']
    }
    important_features.append(feature)

# Create TAM_BI_important_features dataframe
TAM_BI_important_features = pd.DataFrame(important_features)

# Add rank column based on absolute Estimate value
TAM_BI_important_features['rank'] = TAM_BI_important_features['Estimate'].abs().rank(ascending=False, method='dense')

# Sort by rank
TAM_BI_important_features = TAM_BI_important_features.sort_values('rank')

# Reset index
TAM_BI_important_features = TAM_BI_important_features.reset_index(drop=True)

# Print the results
print("\nTAM_BI_important_features:")
print(TAM_BI_important_features)

# Effect Sizes (Standardized Estimates) for BI paths
print("\nEffect Sizes (Standardized Estimates) for BI paths:")
standardized_estimates = bi_paths.copy()
standardized_estimates['Estimate'] = pd.to_numeric(standardized_estimates['Estimate'], errors='coerce')
standardized_estimates['Std_Err'] = pd.to_numeric(standardized_estimates['Std. Err'], errors='coerce')
standardized_estimates['Std_Estimate'] = standardized_estimates['Estimate'] / standardized_estimates['Std_Err']
standardized_estimates['Std_Estimate'] = standardized_estimates['Std_Estimate'].replace([np.inf, -np.inf], np.nan)
print(standardized_estimates[['lval', 'rval', 'Std_Estimate']])

# Plotting the most important features
plt.figure(figsize=(10, 6))
plt.barh(TAM_BI_important_features['from'], TAM_BI_important_features['Estimate'])
plt.xlabel('Estimate')
plt.ylabel('Path')
plt.title('TAM AR VTO Most Important Features Affecting BI')
plt.gca().invert_yaxis()  # Invert y-axis to show highest estimate at the top
for i, v in enumerate(TAM_BI_important_features['Estimate']):
    plt.text(v, i, f' {v:.3f}', va='center')
plt.tight_layout()
plt.show()
# Out:
# Total variance of BI: 0.35264898260455624
# Path Coefficients related to BI:
#    lval op  rval  Estimate  Std. Err   z-value   p-value
# 13   BI  ~    PU  0.352649  0.065377  5.394113       0.0
# 14   BI  ~  PEOU  0.147072  0.088476  1.662276  0.096458
# 15   BI  ~    HM  0.511131   0.07258  7.042279       0.0
#
# Model Fit Statistics:
#        DoF  DoF Baseline        chi2  chi2 p-value  chi2 Baseline       CFI  \
# Value  332           380  835.571599           0.0   10931.416846  0.952275
#
#             GFI      AGFI       NFI       TLI     RMSEA         AIC       BIC  \
# Value  0.923562  0.912511  0.923562  0.945374  0.059881  144.058625  443.7389
#
#          LogLik
# Value  1.970688
#
# TAM_model_BI_R_squared:
#   model_name  BI_R_squared run_type
# 0        TAM      0.953077  Initial
#
# TAM_BI_important_features:
#    from  to  Estimate   Std_Err   z-value       p-value  rank
# 0    HM  BI  0.511131  0.072580  7.042279  1.891154e-12   1.0
# ...

# %%
stats
# Out:
#        DoF  DoF Baseline        chi2  chi2 p-value  chi2 Baseline       CFI  \
# Value  209           253  439.464082           0.0    9285.461348  0.974485
#
#             GFI      AGFI       NFI       TLI     RMSEA         AIC  \
# Value  0.952672  0.942708  0.952672  0.969113  0.051057  131.927056
#
#               BIC    LogLik
# Value  403.259198  1.036472

# %% [markdown]
# ### Create TAM model to predict BI

# %%
import pandas as pd
import numpy as np
from semopy import Model, calc_stats
import matplotlib.pyplot as plt

# Define the model specification
model_spec = """
# Measurement model
PU =~ PU1 + PU2 + PU3 + PU4
PEOU =~ PE1 + PE2 + PE3
BI =~ BI1 + BI2 + BI3
PPV =~PPV1 + PPV2 + PPV3
SOI =~ SOI1+ SOI2 +SOI3 + SOI4
SEI =~ SEI1 + SEI2 + SEI3
HM =~ HM1 +HM2 + HM3
AT =~ AT1 + AT2 + AT3

# Structural model
PEOU ~  PPV + SOI + SEI + AGE_num + Gender_num
PU ~ HM + PEOU + PPV + SOI + SEI + AGE_num + Gender_num
HM ~ PEOU
BI ~ AGEPEOU_centered
BI ~ GenderPEOU_centered
BI ~ AGEPU_centered
BI ~ GenderPU_centered
BI ~ PU
BI ~ PEOU
BI ~ HM
"""

# Create and fit the model
model = Model(model_spec)
res = model.fit(df_survey_cleaned)

# Get the parameter estimates
estimates = model.inspect()
print(f"estimates: {estimates}")

# Extract all path coefficients (structural relationships)
all_paths = estimates[estimates['op'] == '~'].copy()

print(f"all_paths: {all_paths}")

# Set display options to show all rows and columns
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', None)

# Calculate and print fit statistics
fit_stats = calc_stats(model)
print("\nModel Fit Statistics:")
print(fit_stats)

# Convert 'Estimate' and 'Std. Err' to numeric, replacing non-numeric values with NaN
all_paths['Estimate'] = pd.to_numeric(all_paths['Estimate'], errors='coerce')
all_paths['Std. Err'] = pd.to_numeric(all_paths['Std. Err'], errors='coerce')

# Add absolute value of estimates for ranking
all_paths['Abs_Estimate'] = all_paths['Estimate'].abs()

# Rank paths based on absolute estimate
all_paths['Rank'] = all_paths['Abs_Estimate'].rank(ascending=False, method='dense')

# Sort by rank
all_paths = all_paths.sort_values('Rank')

# Reset index
all_paths = all_paths.reset_index(drop=True)

# Select relevant columns and rename for clarity
all_paths = all_paths[['lval', 'rval', 'Estimate', 'Std. Err', 'z-value', 'p-value', 'Rank']]
all_paths.columns = ['To', 'From', 'Estimate', 'Std_Err', 'z_value', 'p_value', 'Rank']

# Print all paths
print('*********************************************************************************************')
print("All Structural Paths:")
print(all_paths)

# R-squared values for endogenous variables
r_squared = estimates[estimates['op'] == '~~'].copy()
r_squared['R_squared'] = 1 - pd.to_numeric(r_squared['Estimate'], errors='coerce')
r_squared = r_squared[r_squared['lval'] == r_squared['rval']]  # Only keep diagonal elements
r_squared = r_squared[['lval', 'R_squared']]
r_squared.columns = ['Variable', 'R_squared']
print("\nR-squared values for endogenous variables:")
print(r_squared)

# Find the R-squared of BI
bi_r_squared = r_squared[r_squared['Variable'] == 'BI']['R_squared'].values

if len(bi_r_squared) > 0:
    bi_r_squared = bi_r_squared[0]
    # Create TAM_model_BI_R_squared dataframe
    TAM_model_BI_R_squared = pd.DataFrame({
        'model_name': ['TAM'],
        'BI_R_squared': [bi_r_squared],
        'run_type': ['Initial']
    })
    print("\nTAM_model_BI_R_squared:")
    print(TAM_model_BI_R_squared)
else:
    print("\nWarning: R-squared for BI not found in the DataFrame.")

# Extract only path coefficients related to BI
paths = [('BI', 'PU'), ('BI', 'PEOU'), ('BI', 'HM'), ('BI',  'AGEPU_centered'), ('BI',  'GenderPU_centered'), ('BI',  'AGEPEOU_centered'),('BI',  'GenderPEOU_centered'), ('BI','BI')]

# Create a list to store the important features
important_features = []

for path in paths:
    coef = estimates[(estimates['lval'] == path[0]) & 
                     (estimates['op'] == '~') & 
                     (estimates['rval'] == path[1])]
    if not coef.empty:
        feature = {
            'from': path[1],
            'to': path[0],
            'Estimate': coef['Estimate'].values[0],
            'Std_Err': coef['Std. Err'].values[0],
            'z-value': coef['z-value'].values[0],
            'p-value': coef['p-value'].values[0]
        }
        important_features.append(feature)

# Create TAM_BI_important_features dataframe
TAM_BI_important_features = pd.DataFrame(important_features)

# Add rank column based on absolute Estimate value
TAM_BI_important_features['rank'] = TAM_BI_important_features['Estimate'].abs().rank(ascending=False, method='dense')

# Sort by rank
TAM_BI_important_features = TAM_BI_important_features.sort_values('rank')

# Reset index
TAM_BI_important_features = TAM_BI_important_features.reset_index(drop=True)

# Print the results
print("TAM_BI_important_features:")
print(TAM_BI_important_features)

print("\nEffect Sizes (Standardized Estimates):")
standardized_estimates = estimates[estimates['op'] == '~'].copy()
standardized_estimates['Estimate'] = pd.to_numeric(standardized_estimates['Estimate'], errors='coerce')
standardized_estimates['Std_Err'] = pd.to_numeric(standardized_estimates['Std. Err'], errors='coerce')
standardized_estimates['Std_Estimate'] = standardized_estimates['Estimate'] / standardized_estimates['Std_Err']
standardized_estimates['Std_Estimate'] = standardized_estimates['Std_Estimate'].replace([np.inf, -np.inf], np.nan)
print(standardized_estimates[['lval', 'rval', 'Std_Estimate']])

# Plotting the most important features
plt.figure(figsize=(10, 6))
plt.barh(TAM_BI_important_features['from'], TAM_BI_important_features['Estimate'])
plt.xlabel('Estimate')
plt.ylabel('Path')
plt.title('Most Important Features Affecting BI')
plt.gca().invert_yaxis()  # Invert y-axis to show highest estimate at the top
for i, v in enumerate(TAM_BI_important_features['Estimate']):
    plt.text(v, i, f' {v:.3f}', va='center')
plt.tight_layout()
plt.show()

# Total effects (if available)
if hasattr(model, 'effects'):
    total_effects = model.effects()
    print("\nTotal Effects:")
    print(total_effects)
else:
    print("\nTotal effects not available for this model.")
# Out:
# estimates:     lval  op                 rval  Estimate  Std. Err    z-value   p-value
# 0   PEOU   ~                  PPV  0.708953  0.119727   5.921389       0.0
# 1   PEOU   ~                  SOI  0.889049  0.189576   4.689678  0.000003
# 2   PEOU   ~                  SEI -0.548190  0.228674  -2.397256  0.016518
# 3   PEOU   ~              AGE_num  0.003042  0.023506   0.129405  0.897037
# 4   PEOU   ~           Gender_num -0.072961  0.046441  -1.571033  0.116175
# 5     PU   ~                   HM  0.181395  0.071737   2.528612  0.011451
# 6     PU   ~                 PEOU  0.248946  0.349095   0.713118  0.475773
# 7     PU   ~                  PPV  0.870807  0.274794   3.168943   0.00153
# 8     PU   ~                  SOI -0.643425  0.410602  -1.567028  0.117108
# 9     PU   ~                  SEI  0.439862  0.338578   1.299143  0.193895
# 10    PU   ~              AGE_num -0.049926  0.023036  -2.167316  0.030211
# ...

# %%
import pandas as pd
import numpy as np
from semopy import Model
from sklearn.model_selection import KFold
from sklearn.metrics import mean_squared_error, r2_score
import matplotlib.pyplot as plt

# Load your dataset
df_survey_cleaned = pd.read_csv(r'C:\Users\cemcd\Documents\AR VTO Dissertation\AR VTO Dissertation Oct 6\AR VTO Latest Version Oct16 using PCA as Input\df_survey_cleaned.csv')

# Define the TAM model specification
model_spec = """
# Measurement model
PU =~ PU1 + PU2 + PU3 + PU4
PEOU =~ PEOU1 + PEOU2 + PEOU3
BI =~ BI1 + BI2 + BI3
PPV =~ PPV1 + PPV2 + PPV3
SOI =~ SOI1 + SOI2 + SOI3 + SOI4
SEI =~ SEI1 + SEI2 + SEI3
HM =~ HM1 + HM2 + HM3
AT =~ AT1 + AT2 + AT3

# Structural model
PEOU ~ PPV + SOI + SEI + AGE_num + Gender_num
PU ~ HM + PEOU + PPV + SOI + SEI + AGE_num + Gender_num
HM ~ PEOU
BI ~ AGEPEOU_centered
BI ~ GenderPEOU_centered
BI ~ AGEPU_centered
BI ~ GenderPU_centered
BI ~ PU
BI ~ PEOU
BI ~ HM
"""

# Initialize KFold and list to store estimates from each fold.
k = 5
kf = KFold(n_splits=k, shuffle=True, random_state=42)
all_estimates = []  # List to store path coefficients from each fold

# Initialize lists to store results for MSE and R^2.
train_mse = []
train_r2 = []
test_mse = []
test_r2 = []

# Perform k-fold cross-validation.
for fold, (train_index, test_index) in enumerate(kf.split(df_survey_cleaned), 1):
    print(f"\nFold {fold}")
    
    # Split the data.
    train_data = df_survey_cleaned.iloc[train_index]
    test_data = df_survey_cleaned.iloc[test_index]
    
    # Fit the SEM model on training data.
    model = Model(model_spec)
    res = model.fit(train_data)
    
    # Extract path coefficients and store them.
    estimates = model.inspect()
    all_estimates.append(estimates)  # Store estimates for this fold
    
    # Calculate BI score for train and test data.
    coef_AGEPEOU_BI = estimates.loc[(estimates['lval'] == 'BI') & (estimates['rval'] == 'AGEPEOU_centered'), 'Estimate'].values[0]
    coef_GenderPEOU_BI = estimates.loc[(estimates['lval'] == 'BI') & (estimates['rval'] == 'GenderPEOU_centered'), 'Estimate'].values[0]
    coef_AGEPU_BI = estimates.loc[(estimates['lval'] == 'BI') & (estimates['rval'] == 'AGEPU_centered'), 'Estimate'].values[0]
    coef_GenderPU_BI = estimates.loc[(estimates['lval'] == 'BI') & (estimates['rval'] == 'GenderPU_centered'), 'Estimate'].values[0]
    coef_PU_BI = estimates.loc[(estimates['lval'] == 'BI') & (estimates['rval'] == 'PU'), 'Estimate'].values[0]
    coef_PEOU_BI = estimates.loc[(estimates['lval'] == 'BI') & (estimates['rval'] == 'PEOU'), 'Estimate'].values[0]
    coef_HM_BI = estimates.loc[(estimates['lval'] == 'BI') & (estimates['rval'] == 'HM'), 'Estimate'].values[0]

    for data in [train_data, test_data]:
        data.loc[:, 'BI_score'] = (
            coef_AGEPEOU_BI * data['AGEPEOU_centered'] +
            coef_GenderPEOU_BI * data['GenderPEOU_centered'] +
            coef_AGEPU_BI * data['AGEPU_centered'] +
            coef_GenderPU_BI * data['GenderPU_centered'] +
            coef_PU_BI * data['PU'] +
            coef_PEOU_BI * data['PEOU'] +
            coef_HM_BI * data['HM']
        )
    
    # Calculate MSE and R-squared for this fold.
    train_mse.append(mean_squared_error(train_data['BI'], train_data['BI_score']))
    train_r2.append(r2_score(train_data['BI'], train_data['BI_score']))
    test_mse.append(mean_squared_error(test_data['BI'], test_data['BI_score']))
    test_r2.append(r2_score(test_data['BI'], test_data['BI_score']))
    
# Now calculate average path coefficients across all folds.
avg_coefficients = {
    'AGEPEOU_centered': np.mean([est.loc[(est['lval'] == 'BI') & (est['rval'] == 'AGEPEOU_centered'), 'Estimate'].values[0] for est in all_estimates]),
    'GenderPEOU_centered': np.mean([est.loc[(est['lval'] == 'BI') & (est['rval'] == 'GenderPEOU_centered'), 'Estimate'].values[0] for est in all_estimates]),
    'AGEPU_centered': np.mean([est.loc[(est['lval'] == 'BI') & (est['rval'] == 'AGEPU_centered'), 'Estimate'].values[0] for est in all_estimates]),
    'GenderPU_centered': np.mean([est.loc[(est['lval'] == 'BI') & (est['rval'] == 'GenderPU_centered'), 'Estimate'].values[0] for est in all_estimates]),
    'PU': np.mean([est.loc[(est['lval'] == 'BI') & (est['rval'] == 'PU'), 'Estimate'].values[0] for est in all_estimates]),
    'PEOU': np.mean([est.loc[(est['lval'] == 'BI') & (est['rval'] == 'PEOU'), 'Estimate'].values[0] for est in all_estimates]),
    'HM': np.mean([est.loc[(est['lval'] == 'BI') & (est['rval'] == 'HM'), 'Estimate'].values[0] for est in all_estimates])
}

# Create a DataFrame for feature importance.
features_importance = pd.DataFrame(avg_coefficients.items(), columns=['Feature', 'Coefficient'])
features_importance['Absolute Coefficient'] = features_importance['Coefficient']

# Sort by absolute coefficient values.
features_importance_sorted = features_importance.sort_values(by='Absolute Coefficient', ascending=False)

print("\nFeature Importance based on Average Path Coefficients:")
print(features_importance_sorted)

# Visualize feature importance.
plt.figure(figsize=(12, 6))
plt.barh(features_importance_sorted['Feature'], features_importance_sorted['Absolute Coefficient'], color='skyblue')
plt.xlabel('Absolute Coefficient Value')
plt.title('Feature Importance based on SEM Model Coefficients')
plt.grid(axis='x')
plt.tight_layout()
plt.show()


# Convert lists to numpy arrays for easier calculations
train_mse = np.array(train_mse)
train_r2 = np.array(train_r2)
test_mse = np.array(test_mse)
test_r2 = np.array(test_r2)

# Print Semopy TAM Regressor results
print("\nSemopy TAM Regressor (Best Model) Results (5-fold Cross-Validation):")
print("--------------------------------")
print(f"Training MSE: {train_mse.mean():.4f} (+/- {train_mse.std() * 2:.4f})")
print(f"Training R^2: {train_r2.mean():.4f} (+/- {train_r2.std() * 2:.4f})")
print(f"Testing MSE: {test_mse.mean():.4f} (+/- {test_mse.std() * 2:.4f})")
print(f"Testing R^2: {test_r2.mean():.4f} (+/- {test_r2.std() * 2:.4f})")

# Create model_metrics dataframe
model_metrics = pd.DataFrame({
    'model_name': ['Semopy TAM Model'],
    'run_type': ['Initial Run'],
    'train_mse_mean': [train_mse.mean()],
    'train_mse_std': [train_mse.std()],
    'train_r2_mean': [train_r2.mean()],
    'train_r2_std': [train_r2.std()],
    'test_mse_mean': [test_mse.mean()],
    'test_mse_std': [test_mse.std()],
    'test_r2_mean': [test_r2.mean()],
    'test_r2_std': [test_r2.std()]})

print(f"Model Metrics': {model_metrics}")

model_metrics.to_csv('TAM_model_metrics')

print('End of TAM script')
# Out:
# Fold 1
# C:\Users\cemcd\AppData\Local\Temp\ipykernel_9440\2468789429.py:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.loc[:, 'BI_score'] = (
# C:\Users\cemcd\AppData\Local\Temp\ipykernel_9440\2468789429.py:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.loc[:, 'BI_score'] = (
# Fold 2
# WARNING:root:Fisher Information Matrix is not PD.Moore-Penrose inverse will be used instead of Cholesky decomposition. See 10.1109/TSP.2012.2208105.
# ...

# %% [markdown]
# ### WIP To be able to Satisfy Hypothesis 3

# %% [markdown]
# ### Original TAM - Davis 1989

# %%
import pandas as pd
from semopy import Model

# Define the model specification
model_spec = """
 
# Measurement model
PU =~ PU1 + PU2 + PU3 + PU4
PEOU =~ PEOU1 + PEOU2 + PEOU3
 
BI =~ BI1 + BI2 + BI3

# Structural model
PEOU ~ AGEPEOU_centered + GenderPEOU_centered
PU ~ PEOU + AGEPU_centered + GenderPU_centered
BI ~ PU + PEOU
 
  
  
"""

# Create the model
model = Model(model_spec)


# Fit the model
res = model.fit(df_survey_cleaned)

# Get the parameter estimates
estimates = model.inspect()

# Find the variance of BI
bi_variance = estimates[estimates['lval'] == 'BI']['Estimate'].values[0]

print(f"Total variance of BI: {bi_variance}")

# Get the path coefficients
path_coefficients = model.inspect()

# Print all path coefficients
print(path_coefficients)

# Extract and print specific path coefficients
# Define the paths we're interested in
paths = [
    ('PU', 'AGE_num'), ('PU', 'Gender_num'), ('PU', 'HM'), ('PU', 'PE'), ('PU', 'PPV'), ('PU', 'SOI'), ('PU', 'SEI'),
    ('PEOU', 'AGE_num'), ('PEOU', 'Gender_num'), ('PEOU', 'HM'), ('PEOU', 'PE'), ('PEOU', 'PPV'), ('PEOU', 'SOI'), ('PEOU', 'SEI'),
    ('AT', 'PU'), ('AT', 'PEOU'),
    ('BI', 'AT'), ('BI', 'PU'), ('BI', 'PEOU'),
    ('HM', 'AGE_num'), ('HM', 'Gender_num'),
    ('PPV', 'AGE_num'), ('PPV', 'Gender_num'),
    ('SOI', 'AGE_num'), ('SOI', 'Gender_num'),
    ('SEI', 'AGE_num'), ('SEI', 'Gender_num'),
    ('PE', 'AGE_num'), ('PE', 'Gender_num')
]

# Extract and print specific path coefficients
print("Path Coefficients:")
for path in paths:
    coef = path_coefficients[(path_coefficients['lval'] == path[0]) & 
                             (path_coefficients['op'] == '~') & 
                             (path_coefficients['rval'] == path[1])]['Estimate']
    if not coef.empty:
        print(f"Path coefficient from {path[1]} to {path[0]}: {coef.values[0]}")
    else:
        print(f"Path coefficient from {path[1]} to {path[0]}: Not found")
# Get model fit indices
fit_indices = semopy.calc_stats(model)

# Set display options to show all rows and columns
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', None)

# Display path coefficients
print("Path Coefficients:")
print(path_coefficients)
print("\n")

# Display model fit indices
print("Model Fit Indices:")
for index, value in fit_indices.items():
    if isinstance(value, float):
        print(f"{index}: {value:.6f}")
    else:
        print(f"{index}: {value}")

# Display specific fit indices if available
print("\nSpecific Fit Indices:")
if 'CFI' in fit_indices.index:
    print(f"CFI: {fit_indices['CFI']:.6f}")
if 'RMSEA' in fit_indices.index:
    print(f"RMSEA: {fit_indices['RMSEA']:.6f}")
if 'SRMR' in fit_indices.index:
    print(f"SRMR: {fit_indices['SRMR']:.6f}")

# Reset display options to default (optional)
pd.reset_option('display.max_rows')
pd.reset_option('display.max_columns')
pd.reset_option('display.width')
pd.reset_option('display.max_colwidth')
# Out:
# Total variance of BI: 0.7571303483193516
#      lval  op                 rval  Estimate  Std. Err    z-value   p-value
# 0    PEOU   ~     AGEPEOU_centered  0.368274  0.020035  18.381372       0.0
# 1    PEOU   ~  GenderPEOU_centered  0.223467  0.050018   4.467714  0.000008
# 2      PU   ~                 PEOU  0.298597  0.037199   8.027098       0.0
# 3      PU   ~       AGEPU_centered  0.265698  0.022248  11.942773       0.0
# 4      PU   ~    GenderPU_centered  0.177722  0.046899   3.789458  0.000151
# 5      BI   ~                   PU  0.757130  0.072619  10.426074       0.0
# 6      BI   ~                 PEOU  0.089084  0.064521   1.380686  0.167376
# 7     PU1   ~                   PU  1.000000         -          -         -
# 8     PU2   ~                   PU  0.965146  0.040964  23.561101       0.0
# 9     PU3   ~                   PU  0.941811  0.044865   20.99234       0.0
# 10    PU4   ~                   PU  0.963088  0.042472  22.675658       0.0
# ...

# %% [markdown]
# ### Key take aways - possible non linear relations

# %% [raw]
# Based on the provided results of Technology Acceptance Model (TAM) with a focus on Hedonic Motivation (HM), Social Identity (SOI), Self-Identity (SEI), and Perceived Product Value (PPV):
#
# 1. Direct Effects on Behavioral Intention (BI):
#
# a) Hedonic Motivation (HM) → BI:
#    - Estimate: 0.486490
#    - p-value: < 0.001 (highly significant)
#    - Rank: 1
#    - HM has the strongest direct effect on BI, indicating that the enjoyment or pleasure derived from using the technology is the most crucial factor in determining user adoption.
#
# b) Perceived Usefulness (PU) → BI:
#    - Estimate: 0.466323
#    - p-value: < 0.001 (highly significant)
#    - Rank: 2
#    - PU has the second strongest effect on BI, suggesting that the perceived utility of the technology significantly influences intention to use.
#
# c) Perceived Ease of Use (PEOU) → BI:
#    - Estimate: 0.130666
#    - p-value: 0.134513 (not significant at 0.05 level)
#    - Rank: 3
#    - PEOU has a positive but non-significant direct effect on BI, indicating that ease of use might influence BI through other factors rather than directly.
#
# 2. Effects on Perceived Ease of Use (PEOU):
#
# a) SOI → PEOU:
#    - Estimate: 0.843640
#    - p-value: 0.000001 (highly significant)
#    - Social Identity has a strong positive effect on PEOU, suggesting that users who identify with the social group associated with the technology find it easier to use.
#
# b) PPV → PEOU:
#    - Estimate: 0.722020
#    - p-value: < 0.001 (highly significant)
#    - Perceived Product Value significantly influences PEOU, indicating that users who perceive higher value in the product also find it easier to use.
#
# c) SEI → PEOU:
#    - Estimate: -0.511859
#    - p-value: 0.015068 (significant)
#    - Interestingly, Self-Identity has a negative effect on PEOU, which might suggest that users with a strong self-identity related to the technology might perceive it as more complex or sophisticated.
#
# 3. Effects on Perceived Usefulness (PU):
#
# a) PPV → PU:
#    - Estimate: 1.051326
#    - p-value: < 0.001 (highly significant)
#    - Perceived Product Value has the strongest effect on PU, indicating that users who perceive higher value in the product also find it more useful.
#
# b) HM → PU:
#    - Estimate: 0.197730
#    - p-value: 0.001558 (significant)
#    - Hedonic Motivation positively influences PU, suggesting that enjoyment in using the technology also contributes to its perceived usefulness.
#
# c) SOI → PU:
#    - Estimate: -0.342850
#    - p-value: 0.029983 (significant)
#    - Social Identity has a negative effect on PU, which is an unexpected finding that might require further investigation.
#
# 4. Other Notable Relationships:
#
# a) PEOU → HM:
#    - Estimate: 0.867872
#    - p-value: < 0.001 (highly significant)
#    - Perceived Ease of Use strongly influences Hedonic Motivation, suggesting that users find more enjoyment in technologies that are easier to use.
#
# 5. Model Fit and Explanatory Power:
#
# - The model explains 95.71% of the variance in Behavioral Intention (R-squared: 0.957061), which is exceptionally high.
# - The model also explains 96.06% of PEOU and 95.15% of PU, indicating strong predictive power for these key constructs.
# - The overall model fit (CFI: 0.904378, RMSEA: 0.08153) suggests an acceptable to good fit, although there might be room for improvement.
#
# Interpretation:
#
# 1. Hedonic Motivation emerges as the most critical factor in determining Behavioral Intention, highlighting the importance of enjoyment and pleasure in technology adoption.
#
# 2. The strong influence of Perceived Product Value on both PEOU and PU underscores the importance of communicating the value proposition of the technology to potential users.
#
# 3. Social Identity plays a complex role, positively influencing PEOU but negatively affecting PU. This suggests that social factors can make a technology seem easier to use but might not necessarily contribute to its perceived usefulness.
#
# 4. The negative effect of Self-Identity on PEOU is intriguing and might indicate that users who strongly identify with the technology perceive it as more sophisticated or complex.
#
# 5. The strong relationship between PEOU and HM suggests that making a technology easier to use can significantly enhance its enjoyment factor, which in turn is the strongest predictor of adoption intention.
#
# 6. The model's high explanatory power for BI, PEOU, and PU indicates that it captures the key factors influencing technology acceptance very well. However, such high R-squared values also warrant caution and further investigation to ensure there's no overfitting.
#
# In conclusion, this model emphasizes the importance of hedonic aspects, perceived value, and social factors in technology acceptance, while also highlighting complex interactions between these factors. To promote technology adoption, focus should be on enhancing enjoyment, clearly communicating product value, and considering the social context of use.
#
# Citations:
# [1] https://ppl-ai-file-upload.s3.amazonaws.com/web/direct-files/4024686/ded36539-caac-43a9-9f92-050f18ba1436/paste.txt
# [2] https://ppl-ai-file-upload.s3.amazonaws.com/web/direct-files/4024686/a050371f-a275-4478-bcdb-bb7dad59cd7b/paste-2.txt
# [3] https://ppl-ai-file-upload.s3.amazonaws.com/web/direct-files/4024686/7762d117-900a-415a-8149-a0e32d43ed63/paste.txt
#
# 1. Direct effects on Perceived Ease of Use (PEOU):
#
#    - AGE_num → PEOU:
#      Estimate: 0.003205
#      p-value: 0.891249 (not significant)
#
#    - Gender_num → PEOU:
#      Estimate: -0.072512
#      p-value: 0.117432 (not significant)
#
# 2. Direct effects on Perceived Usefulness (PU):
#
#    - AGE_num → PU:
#      Estimate: -0.049159
#      p-value: 0.029147 (significant)
#
#    - Gender_num → PU:
#      Estimate: 0.074751
#      p-value: 0.093705 (marginally significant)
#
# 3. Interaction effects on Behavioral Intention (BI):
#
#    - AGEPEOU_centered → BI:
#      Estimate: 0.044353
#      p-value: 0.178925 (not significant)
#
#    - GenderPEOU_centered → BI:
#      Estimate: -0.082458
#      p-value: 0.327871 (not significant)
#
#    - AGEPU_centered → BI:
#      Estimate: -0.075741
#      p-value: 0.036141 (significant)
#
#    - GenderPU_centered → BI:
#      Estimate: 0.067057
#      p-value: 0.47055 (not significant)
#
# Interpretation:
#
# 1. Age:
#    - Has no significant direct effect on PEOU.
#    - Has a small but significant negative effect on PU, suggesting that older users might perceive the technology as slightly less useful.
#    - The interaction of age with PU (AGEPU_centered) has a significant negative effect on BI, indicating that the influence of PU on BI might decrease with age.
#
# 2. Gender:
#    - Has no significant direct effect on PEOU.
#    - Has a marginally significant positive effect on PU, suggesting that one gender (likely coded as 1) might perceive the technology as slightly more useful.
#    - None of the gender interactions (with PEOU or PU) significantly affect BI.
#
# Overall, the effects of age and gender are relatively small compared to the main effects of PU, PEOU, and HM on BI. Age seems to have a more noticeable impact than gender, particularly in how it moderates the relationship between PU and BI. However, these demographic factors play a minor role in the overall model compared to the core TAM constructs.
#
# Citations:
# [1] https://ppl-ai-file-upload.s3.amazonaws.com/web/direct-files/4024686/ded36539-caac-43a9-9f92-050f18ba1436/paste.txt
# [2] https://ppl-ai-file-upload.s3.amazonaws.com/web/direct-files/4024686/a050371f-a275-4478-bcdb-bb7dad59cd7b/paste-2.txt

# %% [markdown]
# ### End of TAM

# %%
print('end of TAM Script')
# Out:
# end of TAM Script
