# %% [markdown]
# # 2.  Dissertation - AR VTO-Latest Version 09172024-Data Exploration

# %%
#print(sklearn.__version__)

# %%
#!pip freeze > requirements.txt

# %% [raw]
# 1.  Dissertation - AR VTO-Latest Version 09172024 Cleaned Dataset-Copy1
# 2.  Dissertation - AR VTO-Latest Version 09172024-Data Exploration-Copy1
# 3.  Dissertation - AR VTO-Latest Version 09172024- Create PCA Feature List
# 4.  Dissertation - AR VTO-Latest Version 09172024-BuildTestHarnesses-with extra models
# 5.  Dissertation - AR VTO-Latest Version TAM
# 6.  Dissertation - AR VTO-Latest Version Gradient Boost
# 7.  Dissertation - AR VTO-Latest Version KNN
# 8.  Dissertation - AR VTO-Latest Version Lasso
# 9.  Dissertation - AR VTO-Latest Version MLP
# 10. Dissertation - AR VTO-Latest Version MLR
# 11. Dissertation - AR VTO-Latest Version RF
# 12. Dissertation - AR VTO-Latest Version Ridge
# 13. Dissertation - AR VTO-Latest Version SVR
# 13. Dissertation - AR VTO-Latest Version XGBoost
# 14. Dissertation - AR VTO - Stats Model MLR
# 15. Dissertation - AR VTO-Latest Version Final Model

# %% [markdown]
# ### Change Log

# %% [raw]
# 1. 10/23 Changed title to match purpose of notebook

# %% [raw]
# 2. 10/23 Chanage to read df_survey_cleaned from current directory - df_survey_cleaned = pd.read_csv('df_survey_cleaned.csv')

# %% [raw]
# 3. 10/23 added print('End of Script')

# %% [raw]
# 4. 10/23 removed code/info after 'End of Data Exploration'

# %% [markdown]
# # Begin Code

# %%
import pandas as pd
import numpy as np
from numpy import arange
import scipy.stats as stats
from scipy.stats import spearmanr

from sklearn.preprocessing import StandardScaler

from sklearn.metrics import mean_squared_error, r2_score
# Load libraries
import numpy
from numpy import arange
from matplotlib import pyplot
from pandas import read_csv
from pandas import set_option
from pandas.plotting import scatter_matrix
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Lasso
from sklearn.linear_model import ElasticNet
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.neural_network import MLPRegressor
from sklearn.svm import SVR

from sklearn.metrics import mean_squared_error
from sklearn.datasets import make_regression
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import Lasso
from sklearn.metrics import mean_squared_error, r2_score
import statsmodels.api as sm
import semopy
from semopy import Model, Optimizer, calc_stats
#from pdpbox import pdp, get_dataset, info_plots
from sklearn.metrics import mutual_info_score
from sklearn import metrics
#import eli5
#from eli5.sklearn import PermutationImportance

# Machine Learning
from sklearn.model_selection import train_test_split, cross_val_score, cross_validate, KFold, GridSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score, mutual_info_score
from sklearn.datasets import make_regression
from sklearn.pipeline import Pipeline
 
# Models
from sklearn.linear_model import LinearRegression, Lasso, ElasticNet
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.neural_network import MLPRegressor
from sklearn.svm import SVR
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor, ExtraTreesRegressor, AdaBoostRegressor
from sklearn.cluster import KMeans

# Feature Selection and Dimensionality Reduction
from sklearn.decomposition import PCA
#from eli5.sklearn import PermutationImportance

# Statistical Analysis
import statsmodels.api as sm
from statsmodels.stats.outliers_influence import variance_inflation_factor
from scipy.stats import chi2_contingency
from factor_analyzer import FactorAnalyzer
import semopy
from semopy import Model, Optimizer, calc_stats

#Visualization
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib import pyplot
from pandas.plotting import scatter_matrix

#Model Interpretation
#import eli5

# Language Translation
from googletrans import Translator
translator = Translator()
from translate import Translator

translator = Translator(to_lang="en", from_lang="vi")
translation_1 = translator.translate("nữ")
translation_0 = translator.translate("nam")

print(f"Translation of 'nữ': {translation_1}")
print(f"Translation of 'nam': {translation_0}")

# Miscellaneous
# Set display options to show all columns
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
import warnings
warnings.filterwarnings("ignore", category=UserWarning)
warnings.filterwarnings("ignore", category=RuntimeWarning)
# Out:
# Translation of 'nữ': female
# Translation of 'nam': male

# %%
df_survey_cleaned = pd.read_csv('df_survey_cleaned.csv')

# %%
#display column headers and the first row

df_survey_cleaned.head(2)
# Out:
#              Timestamp  AR_Knowledgeable  familiar_with_technology  \
# 0  13/10/2022 11:08:13               4.0                       3.0
# 1  13/10/2022 13:29:22               3.0                       3.0
#
#    use_AR_everyday        use_in_all_aspects  Virtual_shopping_environment  \
# 0              3.0  Du lịch ảo / trải nghiệm                           3.0
# 1              3.0                   Mua sắm                           3.0
#
#    Virtual_tour  Visualize_model  Emulation  PE1  PE2  PE3  PE4  SOI1  SOI2  \
# 0           3.0              3.0        3.0  4.0  4.0  4.0  4.0   3.0   3.0
# 1           3.0              3.0        3.0  3.0  3.0  3.0  3.0   3.0   3.0
#
#    SOI3  SOI4  SEI1  SEI2  SEI3  PEOU1  PEOU2  PEOU3  PU1  PU2  PU3  PU4   B1  \
# 0   3.0   3.0   3.0   3.0   3.0    4.0    4.0    4.0  4.0  3.0  3.0  3.0  3.0
# 1   3.0   3.0   3.0   3.0   3.0    3.0    3.0    3.0  3.0  3.0  3.0  3.0  3.0
#
#    AT1  AT2  AT3  PPV1  PPV2  PPV3  HM1  HM2  HM3  BI1  BI2  BI3  BI4 Gender  \
# 0  3.0  4.0  4.0   4.0   4.0   4.0  4.0  4.0  4.0  3.0  4.0  4.0  4.0    nam
# 1  3.0  3.0  3.0   3.0   3.0   3.0  3.0  3.0  3.0  3.0  3.0  3.0  3.0     nữ
#
#               AGE  Location Gender_eng Gender_vietnamese  Gender_num  \
# 0    Trên 40 tuổi  miền Bắc       male               nam           0
# 1  20 đến 29 tuổi  miền Bắc     female                nữ           1
#
#               AGE_eng  AGE_num  Age_vietnamese      Usage_1      Usage_2  \
# 0   Over 40 years old        3    Trên 40 tuổi  Du lịch ảo   trải nghiệm
# 1  20 to 29 years old        1  20 đến 29 tuổi      Mua sắm          NaN
#
#   Usage_3 Usage_4 Usage_5 Usage_6 Usage_7   Usage_1_en  Usage_2_en Usage_3_en  \
# 0     NaN     NaN     NaN     NaN     NaN  Du lịch ảo   experience        NaN
# 1     NaN     NaN     NaN     NaN     NaN     Shopping         NaN        NaN
#
#   Usage_4_en Usage_5_en Usage_6_en Usage_7_en  use_type_cnts    BI   PE  SOI  \
# 0        NaN        NaN        NaN        NaN              2  3.75  4.0  3.0
# 1        NaN        NaN        NaN        NaN              1  3.00  3.0  3.0
#
#    SEI   HM        AT  PPV    PU  PEOU  PE_centered  SOI_centered  \
# 0  3.0  4.0  3.666667  4.0  3.25   4.0     0.205189     -0.714033
# 1  3.0  3.0  3.000000  3.0  3.00   3.0    -0.794811     -0.714033
#
#    SEI_centered  HM_centered  AT_centered  PPV_centered  PU_centered  \
# 0      -0.72327     0.130503    -0.166667      0.211478    -0.568396
# 1      -0.72327    -0.869497    -0.833333     -0.788522    -0.818396
#
#    PEOU_centered  AR_Knowledgeable_centered  \
# 0       0.304245                   1.025943
# 1      -0.695755                   0.025943
#
#    familiar_with_technology_centered  use_AR_everyday_centered  \
# 0                           0.016509                  0.325472
# 1                           0.016509                  0.325472
#
#    Virtual_shopping_environment_centered  Virtual_tour_centered  \
# 0                               0.134434               0.233491
# 1                               0.134434               0.233491
#
#    Visualize_model_centered  Emulation_centered  AGEGender_centered  \
# 0                  0.108491            0.228774                   0
# 1                  0.108491            0.228774                   1
#
#    AGEAR_Knowledgeable  AGEfamiliar_with_technology  AGEuse_AR_everyday  \
# 0             3.077830                     0.049528            0.976415
# 1             0.025943                     0.016509            0.325472
#
#    AGEVirtual_shopping_environment  AGEVirtual_tour  AGEVisualize_model  \
# 0                         0.403302         0.700472            0.325472
# 1                         0.134434         0.233491            0.108491
#
#    AGEEmulation  GenderAR_Knowledgeable  Genderfamiliar_with_technology  \
# 0      0.686321                0.000000                        0.000000
# 1      0.228774                0.025943                        0.016509
#
#    Genderuse_AR_everyday  GenderVirtual_shopping_environment  \
# 0               0.000000                            0.000000
# 1               0.325472                            0.134434
#
#    GenderVirtual_tour  GenderVisualize_model  GenderEmulation  \
# 0            0.000000               0.000000         0.000000
# 1            0.233491               0.108491         0.228774
#
#    GenderPU_centered  GenderPE_centered  GenderPEOU_centered  \
# 0          -0.000000           0.000000             0.000000
# 1          -0.818396          -0.794811            -0.695755
#
#    GenderAT_centered  GenderPPV_centered  GenderHM_centered  \
# 0          -0.000000            0.000000           0.000000
# 1          -0.833333           -0.788522          -0.869497
#
#    GenderSOI_centered  GenderSEI_centered  AGEPEOU_centered  AGEPU_centered  \
# 0           -0.000000            -0.00000          0.912736       -1.705189
# 1           -0.714033            -0.72327         -0.695755       -0.818396
#
#    AGESOI_centered  AGESEI_centered  AGEPPV_centered  AGEHM_centered  \
# 0        -2.142099        -2.169811         0.634434        0.391509
# 1        -0.714033        -0.723270        -0.788522       -0.869497
#
#    AGEPE_centered  AGEAT_centered  PEAT_centered  HMAT_centered  \
# 0        0.615566       -0.500000      -0.034198      -0.021751
# 1       -0.794811       -0.833333       0.662343       0.724581
#
#    HMPU_centered  HMPEOU_centered  HMSOI_centered  HMSEI_centered  \
# 0      -0.074177         0.039705       -0.093184       -0.094389
# 1       0.711593         0.604957        0.620849        0.628881
#
#    HMPE_centered  HMPPV_centered  SOIPU_centered  SEIPU_centered  \
# 0       0.026778        0.027599        0.405854        0.411104
# 1       0.691086        0.685617        0.584362        0.591922
#
#    SOIPEOU_centered  SEIPEOU_centered  target_variable_num  \
# 0         -0.217241         -0.217241                 3.75
# 1          0.496792          0.496792                 3.00
#
#    target_variable_cat  PE_centered_squared  PE_centered_cubed  \
# 0                    0             0.042102           0.008639
# 1                    0             0.631725          -0.502102
#
#    SOI_centered_squared  SOI_centered_cubed  SEI_centered_squared  \
# 0              0.509843           -0.364045               0.52312
# 1              0.509843           -0.364045               0.52312
#
#    SEI_centered_cubed  HM_centered_squared  HM_centered_cubed  \
# 0           -0.378357             0.017031           0.002223
# 1           -0.378357             0.756025          -0.657361
#
#    AT_centered_squared  AT_centered_cubed  PPV_centered_squared  \
# 0             0.027778          -0.004630              0.044723
# 1             0.694444          -0.578704              0.621767
#
#    PPV_centered_cubed  PU_centered_squared  PU_centered_cubed  \
# 0            0.009458             0.323074          -0.183634
# 1           -0.490277             0.669772          -0.548139
#
#    PEOU_centered_squared  PEOU_centered_cubed  AGEGender_centered_squared  \
# 0               0.092565             0.028163                           0
# 1               0.484075            -0.336797                           1
#
#    AGEGender_centered_cubed  GenderPU_centered_squared  \
# 0                         0                   0.000000
# 1                         1                   0.669772
#
#    GenderPU_centered_cubed  GenderPEOU_centered_squared  \
# 0                -0.000000                     0.000000
# 1                -0.548139                     0.484075
#
#    GenderPEOU_centered_cubed  GenderAT_centered_squared  \
# 0                   0.000000                   0.000000
# 1                  -0.336797                   0.694444
#
#    GenderAT_centered_cubed  GenderPPV_centered_squared  \
# 0                -0.000000                    0.000000
# 1                -0.578704                    0.621767
#
#    GenderPPV_centered_cubed  GenderPE_centered_squared  \
# 0                  0.000000                   0.000000
# 1                 -0.490277                   0.631725
#
#    GenderPE_centered_cubed  GenderHM_centered_squared  \
# 0                 0.000000                   0.000000
# 1                -0.502102                   0.756025
#
#    GenderHM_centered_cubed  GenderSOI_centered_squared  \
# 0                 0.000000                    0.000000
# 1                -0.657361                    0.509843
#
#    GenderSOI_centered_cubed  GenderSEI_centered_squared  \
# 0                 -0.000000                     0.00000
# 1                 -0.364045                     0.52312
#
#    GenderSEI_centered_cubed  AGEPEOU_centered_squared  AGEPEOU_centered_cubed  \
# 0                 -0.000000                  0.833087                0.760388
# 1                 -0.378357                  0.484075               -0.336797
#
#    AGEPU_centered_squared  AGEPU_centered_cubed  AGESOI_centered_squared  \
# 0                2.907668             -4.958123                 4.588588
# 1                0.669772             -0.548139                 0.509843
#
#    AGESOI_centered_cubed  AGESEI_centered_squared  AGESEI_centered_cubed  \
# 0              -9.829211                 4.708081             -10.215648
# 1              -0.364045                 0.523120              -0.378357
#
#    AGEPPV_centered_squared  AGEPPV_centered_cubed  AGEHM_centered_squared  \
# 0                 0.402506               0.255364                0.153280
# 1                 0.621767              -0.490277                0.756025
#
#    AGEHM_centered_cubed  AGEPE_centered_squared  AGEPE_centered_cubed  \
# 0              0.060010                0.378922              0.233251
# 1             -0.657361                0.631725             -0.502102
#
#    AGEAT_centered_squared  AGEAT_centered_cubed  PEAT_centered_squared  \
# 0                0.250000             -0.125000               0.001170
# 1                0.694444             -0.578704               0.438698
#
#    PEAT_centered_cubed  HMAT_centered_squared  HMAT_centered_cubed  \
# 0            -0.000040               0.000473            -0.000010
# 1             0.290568               0.525017             0.380417
#
#    HMPU_centered_squared  HMPU_centered_cubed  HMPEOU_centered_squared  \
# 0               0.005502            -0.000408                 0.001576
# 1               0.506365             0.360325                 0.365972
#
#    HMPEOU_centered_cubed  HMSOI_centered_squared  HMSOI_centered_cubed  \
# 0               0.000063                0.008683             -0.000809
# 1               0.221397                0.385454              0.239309
#
#    HMSEI_centered_squared  HMSEI_centered_cubed  HMPE_centered_squared  \
# 0                0.008909             -0.000841               0.000717
# 1                0.395492              0.248717               0.477600
#
#    HMPE_centered_cubed
# 0             0.000019
# 1             0.330062

# %% [markdown]
# # Data Exploration

# %%
 
df = df_survey_cleaned

 

X = df[['BI', 'AGE_num', 'Gender_num', 'PU_centered','PEOU_centered','PE_centered','HM_centered','SOI_centered', 'SEI_centered',
        'PPV_centered','AGEGender_centered', 'GenderPU_centered', 'GenderPEOU_centered' ,'GenderAT_centered' ,'GenderPPV_centered',
       'GenderPE_centered', 'GenderHM_centered', 'GenderSOI_centered', 'GenderSEI_centered', 'AGEPEOU_centered', 'AGEPU_centered',
       'AGESOI_centered', 'AGESEI_centered', 'AGEPPV_centered', 'AGEHM_centered', 'PEAT_centered', 'HMAT_centered','HMPU_centered', 
        'HMPEOU_centered', 'HMSOI_centered', 'HMSEI_centered', 'HMPE_centered','PE_centered_cubed', 'SOI_centered_squared',
        'SOI_centered_cubed', 'SEI_centered_squared', 'SEI_centered_cubed','HM_centered_squared', 'HM_centered_cubed', 'AT_centered_squared',
        'AT_centered_cubed', 'PPV_centered_squared', 'PPV_centered_cubed', 'PU_centered_squared', 'PU_centered_cubed', 'PEOU_centered_squared',
       'PEOU_centered_cubed', 'AGEGender_centered_squared','AGEGender_centered_cubed', 'GenderPU_centered_squared',
       'AGEGender_centered_cubed', 'GenderPU_centered_squared',
       'GenderPU_centered_cubed', 'GenderPEOU_centered_squared',
       'GenderPEOU_centered_cubed', 'GenderAT_centered_squared',
       'GenderAT_centered_cubed', 'GenderPPV_centered_squared',
       'GenderPPV_centered_cubed', 'GenderPE_centered_squared',
       'GenderPE_centered_cubed', 'GenderHM_centered_squared',
       'GenderHM_centered_cubed', 'GenderSOI_centered_squared',
       'GenderSOI_centered_cubed', 'GenderSEI_centered_squared',
       'GenderSEI_centered_cubed', 'AGEPEOU_centered_squared',
       'AGEPEOU_centered_cubed', 'AGEPU_centered_squared',
       'AGEPU_centered_cubed', 'AGESOI_centered_squared',
       'AGESOI_centered_cubed', 'AGESEI_centered_squared',
       'AGESEI_centered_cubed', 'AGEPPV_centered_squared',
       'AGEPPV_centered_cubed', 'AGEHM_centered_squared',
       'AGEHM_centered_cubed', 'PEAT_centered_squared', 'PEAT_centered_cubed',
       'HMAT_centered_squared', 'HMAT_centered_cubed', 'HMPU_centered_squared',
       'HMPU_centered_cubed', 'HMPEOU_centered_squared',
       'HMPEOU_centered_cubed', 'HMSOI_centered_squared',
       'HMSOI_centered_cubed', 'HMSEI_centered_squared',
       'HMSEI_centered_cubed', 'HMPE_centered_squared', 'HMPE_centered_cubed']]
y = df['BI']

# Sample size check
print(f"Sample size: {len(X)}")
print(f"Number of features: {X.shape[1]}")
print(f"Observations per feature: {len(X) / X.shape[1]:.2f}")
# Out:
# Sample size: 424
# Number of features: 93
# Observations per feature: 4.56

# %% [markdown]
# ## Analyze the target variable

# %%
df_survey_cleaned['BI'].describe()
# Out:
# count    424.000000
# mean       3.797759
# std        0.873460
# min        1.000000
# 25%        3.250000
# 50%        4.000000
# 75%        4.500000
# max        5.000000
# Name: BI, dtype: float64

# %%
 

# Create a figure with two subplots (side by side)
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(8, 4))

# Create a histogram on the first subplot
axes[0].hist(df_survey_cleaned['BI'], bins=10, color='skyblue', edgecolor='black')
axes[0].set_title('Histogram of BI', fontweight='bold')
axes[0].set_xlabel('BI')
axes[0].set_ylabel('Frequency')

# Create a boxplot on the second subplot
axes[1].boxplot(df_survey_cleaned['BI'], vert=True, patch_artist=True)
axes[1].set_title('Boxplot of BI', fontweight='bold')
axes[1].set_xlabel('BI')
axes[1].set_ylabel('Value')

# Adjust the layout to prevent overlap
plt.tight_layout()

# Show the plot
plt.show()

# %%
# List of variables for the heatmap
variables = ['BI', 'PEOU_centered', 'PE_centered', 'PU_centered', 'HM_centered', 'AT_centered', 'PPV_centered', 'SOI_centered', 'SEI_centered']

# Compute the correlation matrix for the specified variables
corr_matrix = df_survey_cleaned[variables].corr()

corr_matrix


# Create the heatmap using seaborn

plt.figure(figsize=(10, 8))
sns.heatmap(corr_matrix, annot=True)

# Set the title and adjust the plot display
plt.title('Heatmap of Variable Correlations')
plt.tight_layout()

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import math
import numpy as np

# Numerical variables to plot against BI
variables_to_plot = ['PEOU_centered', 'PE_centered', 'PU_centered', 'HM_centered', 'AT_centered', 'PPV_centered', 'SOI_centered', 'SEI_centered']

# Calculate the number of rows and columns needed
num_variables = len(variables_to_plot)
num_cols = 4  # You can adjust this if you want a different number of columns
num_rows = math.ceil(num_variables / num_cols)

# Create a figure and a grid of subplots
fig, axes = plt.subplots(nrows=num_rows, ncols=num_cols, figsize=(20, 5*num_rows))

# Add a main title to the figure
fig.suptitle(' Interaction Features Correlation with BI', fontsize=18, y=1.02)

# Flatten the array of axes for easy iteration
axes = axes.flatten()

# Loop through the variables and create a scatter plot for each
for i, variable in enumerate(variables_to_plot):
    # Select the subplot
    ax = axes[i]
    
    # Create the scatter plot
    ax.scatter(df_survey_cleaned[variable], df_survey_cleaned['BI'], alpha=0.5)
    
    # Set the title and labels with increased font size
    ax.set_title(f'BI vs. {variable}', fontsize=12)
    ax.set_xlabel(variable, fontsize=10)
    ax.set_ylabel('BI', fontsize=10)
    
    # Increase tick label font size
    ax.tick_params(axis='both', which='major', labelsize=8)
    
    # Add a trend line
    z = np.polyfit(df_survey_cleaned[variable], df_survey_cleaned['BI'], 1)
    p = np.poly1d(z)
    ax.plot(df_survey_cleaned[variable], p(df_survey_cleaned[variable]), "r--", alpha=0.8)

# If there are any subplots without data, hide them
for j in range(num_variables, len(axes)):
    axes[j].axis('off')
 
# Adjust the layout to prevent overlap
plt.tight_layout()

# Show the plot
plt.show()

# %% [raw]
# This correlation matrix suggests strong interrelationships among all variables, which could indicate they are measuring related constructs or aspects of a broader concept. The high correlations, particularly with BI, suggest that these factors may be good predictors of behavioral intention in the context being studied. However, Age and Gender have a weak correlation with BI.

# %% [markdown]
# ### Compare BI with the interaction variables

# %% [markdown]
# # BI scatter plots indicatec Possible non linear relationships as indicatedby the curve. PEAT, HMAT, HMPU, HMPEOU, HMSOI, HMSEI,HMPE

# %%
import matplotlib.pyplot as plt
import math
import numpy as np

# Numerical variables to plot against BI
variables_to_plot = ['AGEGender_centered', 'GenderPU_centered', 'GenderPEOU_centered' ,'GenderAT_centered' ,'GenderPPV_centered',
       'GenderPE_centered', 'GenderHM_centered', 'GenderSOI_centered', 'GenderSEI_centered', 'AGEPEOU_centered', 'AGEPU_centered',
       'AGESOI_centered', 'AGESEI_centered', 'AGEPPV_centered', 'AGEHM_centered', 'AGEPE_centered', 'AGEAT_centered', 'PEAT_centered', 'HMAT_centered',
       'HMPU_centered', 'HMPEOU_centered', 'HMSOI_centered', 'HMSEI_centered', 'HMPE_centered']

# Calculate the number of rows and columns needed
num_variables = len(variables_to_plot)
num_cols = 4  # You can adjust this if you want a different number of columns
num_rows = math.ceil(num_variables / num_cols)

# Create a figure and a grid of subplots
fig, axes = plt.subplots(nrows=num_rows, ncols=num_cols, figsize=(20, 5*num_rows))

# Add a main title to the figure
fig.suptitle(' Interaction Features Correlation with BI', fontsize=18, y=1.02)

# Flatten the array of axes for easy iteration
axes = axes.flatten()

# Loop through the variables and create a scatter plot for each
for i, variable in enumerate(variables_to_plot):
    # Select the subplot
    ax = axes[i]
    
    # Create the scatter plot
    ax.scatter(df_survey_cleaned[variable], df_survey_cleaned['BI'], alpha=0.5)
    
    # Set the title and labels with increased font size
    ax.set_title(f'BI vs. {variable}', fontsize=12)
    ax.set_xlabel(variable, fontsize=10)
    ax.set_ylabel('BI', fontsize=10)
    
    # Increase tick label font size
    ax.tick_params(axis='both', which='major', labelsize=8)
    
    # Add a trend line
    z = np.polyfit(df_survey_cleaned[variable], df_survey_cleaned['BI'], 1)
    p = np.poly1d(z)
    ax.plot(df_survey_cleaned[variable], p(df_survey_cleaned[variable]), "r--", alpha=0.8)

# If there are any subplots without data, hide them
for j in range(num_variables, len(axes)):
    axes[j].axis('off')
 
# Adjust the layout to prevent overlap
plt.tight_layout()

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import math

# Numerical variables to plot against BI
variables_to_plot = ['PEAT_centered', 'HMAT_centered', 'HMPU_centered', 'HMPEOU_centered','HMSOI_centered', 'HMSEI_centered', 'HMPE_centered']

# Calculate the number of rows and columns needed
num_variables = len(variables_to_plot)
num_cols = 4  # You can adjust this if you want a different number of columns
num_rows = math.ceil(num_variables / num_cols)

# Create a figure and a grid of subplots
fig, axes = plt.subplots(nrows=num_rows, ncols=num_cols, figsize=(20, 5*num_rows))

# Flatten the array of axes for easy iteration
axes = axes.flatten()

# Loop through the variables and create a scatter plot for each
for i, variable in enumerate(variables_to_plot):
    # Select the subplot
    ax = axes[i]
    
    # Create the scatter plot
    ax.scatter(df_survey_cleaned[variable], df_survey_cleaned['BI'], alpha=0.5)
    
    # Set the title and labels
    ax.set_title(f'BI vs. {variable}')
    ax.set_xlabel(variable)
    ax.set_ylabel('BI')
    


# If there are any subplots without data, hide them
for j in range(num_variables, len(axes)):
    axes[j].axis('off')
 
# Adjust the layout to prevent overlap
plt.tight_layout()

# Show the plot
plt.show()
plt.show()

# %%
# List of variables for the heatmap
variables = ['BI','PEAT_centered', 'HMAT_centered', 'HMPU_centered', 'HMPEOU_centered','HMSOI_centered', 'HMSEI_centered', 'HMPE_centered']

# Compute the correlation matrix for the specified variables
#corr_matrix = df_survey_cleaned[variables].corr()
# Calculate the Spearman correlation matrix
corr_matrix = df_survey_cleaned[variables].corr(method='spearman')

corr_matrix


# Create the heatmap using seaborn

plt.figure(figsize=(10, 8))
sns.heatmap(corr_matrix, annot=True)

# Set the title and adjust the plot display
plt.title('Heatmap of Variable Correlations')
plt.tight_layout()

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import math
import numpy as np

# Numerical variables to plot against BI
variables_to_plot = [
    'PU_centered', 'PEOU_centered', 'PE_centered', 'HM_centered', 'SOI_centered', 'SEI_centered', 'PPV_centered',
    'PEAT_centered', 'HMAT_centered', 'HMPU_centered', 'HMPEOU_centered', 'HMSOI_centered', 'HMSEI_centered', 'HMPE_centered',
    'AGEGender_centered', 'GenderPU_centered', 'GenderPEOU_centered', 'GenderAT_centered', 'GenderPPV_centered',
    'GenderPE_centered', 'GenderHM_centered', 'GenderSOI_centered', 'GenderSEI_centered', 'AGEPEOU_centered', 'AGEPU_centered',
    'AGESOI_centered', 'AGESEI_centered', 'AGEPPV_centered', 'AGEHM_centered', 'AGEPE_centered', 'AGEAT_centered',
    'PE_centered_cubed', 'SOI_centered_squared', 'SOI_centered_cubed', 'SEI_centered_squared', 'SEI_centered_cubed',
    'HM_centered_squared', 'HM_centered_cubed', 'AT_centered_squared', 'AT_centered_cubed', 'PPV_centered_squared', 
    'PPV_centered_cubed', 'PU_centered_squared', 'PU_centered_cubed', 'PEOU_centered_squared', 'PEOU_centered_cubed',
    'AGEGender_centered_squared', 'AGEGender_centered_cubed', 'GenderPU_centered_squared', 'GenderPU_centered_cubed',
    'GenderPEOU_centered_squared', 'GenderPEOU_centered_cubed', 'GenderAT_centered_squared', 'GenderAT_centered_cubed',
    'GenderPPV_centered_squared', 'GenderPPV_centered_cubed', 'GenderPE_centered_squared', 'GenderPE_centered_cubed',
    'GenderHM_centered_squared', 'GenderHM_centered_cubed', 'GenderSOI_centered_squared', 'GenderSOI_centered_cubed',
    'GenderSEI_centered_squared', 'GenderSEI_centered_cubed', 'AGEPEOU_centered_squared', 'AGEPEOU_centered_cubed',
    'AGEPU_centered_squared', 'AGEPU_centered_cubed', 'AGESOI_centered_squared', 'AGESOI_centered_cubed',
    'AGESEI_centered_squared', 'AGESEI_centered_cubed', 'AGEPPV_centered_squared', 'AGEPPV_centered_cubed',
    'AGEHM_centered_squared', 'AGEHM_centered_cubed', 
    'PEAT_centered_squared', 'PEAT_centered_cubed', 'HMAT_centered_squared', 'HMAT_centered_cubed', 'HMPU_centered_squared',
    'HMPU_centered_cubed', 'HMPEOU_centered_squared', 'HMPEOU_centered_cubed', 'HMSOI_centered_squared',
    'HMSOI_centered_cubed', 'HMSEI_centered_squared', 'HMSEI_centered_cubed', 'HMPE_centered_squared', 'HMPE_centered_cubed'
]

# Calculate the number of rows and columns needed
num_variables = len(variables_to_plot)
num_cols = 4  # You can adjust this if you want a different number of columns
num_rows = math.ceil(num_variables / num_cols)

# Create a figure and a grid of subplots
fig, axes = plt.subplots(nrows=num_rows, ncols=num_cols, figsize=(20, 5*num_rows))

# Flatten the array of axes for easy iteration
axes = axes.flatten()

# Loop through the variables and create a scatter plot for each
for i, variable in enumerate(variables_to_plot):
    # Select the subplot
    ax = axes[i]
    
    # Create the scatter plot
    ax.scatter(df_survey_cleaned[variable], df_survey_cleaned['BI'], alpha=0.5)
    
    # Set the title and labels
    ax.set_title(f'BI vs. {variable}', fontsize=10)
    ax.set_xlabel(variable, fontsize=8)
    ax.set_ylabel('BI', fontsize=8)
    
    # Increase tick label font size
    ax.tick_params(axis='both', which='major', labelsize=6)
    
    # Add a trend line
    z = np.polyfit(df_survey_cleaned[variable], df_survey_cleaned['BI'], 1)
    p = np.poly1d(z)
    ax.plot(df_survey_cleaned[variable], p(df_survey_cleaned[variable]), "r--", alpha=0.8)

# If there are any subplots without data, hide them
for j in range(num_variables, len(axes)):
    axes[j].axis('off')

# Add a main title to the figure
fig.suptitle('Potential Non-Linear Correlation with BI', fontsize=16, y=1.02)

# Adjust the layout to prevent overlap
plt.tight_layout()

# Show the plot
plt.show()

# %% [markdown]
# ## Analyze Age, Gender and BI

# %%
gender_BI_stats = df_survey_cleaned.groupby(['Gender_eng','Gender_num'])['BI'].describe()
gender_BI_stats

# %%
age_BI_stats = df_survey_cleaned.groupby(['AGE_eng','AGE_num'])['BI'].describe()
age_BI_stats

# %%
# Create the crosstab
cross_tab = pd.crosstab(df['AGE_eng'], df['Gender_eng'])

# Calculate row percentages
cross_tab_percentage = cross_tab.div(cross_tab.sum(axis=1), axis=0) * 100

# Add total counts
cross_tab['Total'] = cross_tab.sum(axis=1)
cross_tab_percentage['Total'] = 100

# Round percentages to two decimal places
cross_tab_percentage = cross_tab_percentage.round(2)

# Add column totals
cross_tab.loc['Total'] = cross_tab.sum()
cross_tab_percentage.loc['Total'] = cross_tab_percentage.mean()

cross_tab

# %%
# Create the crosstab
cross_tab = pd.crosstab(df['AGE_eng'], df['Gender_eng'])

# Calculate row percentages
cross_tab_percentage = cross_tab.div(cross_tab.sum(axis=1), axis=0) * 100

# Add total counts
cross_tab['Total'] = cross_tab.sum(axis=1)
cross_tab_percentage['Total'] = 100

# Round percentages to two decimal places
cross_tab_percentage = cross_tab_percentage.round(2)

# Add column totals
cross_tab.loc['Total'] = cross_tab.sum()
cross_tab_percentage.loc['Total'] = cross_tab_percentage.mean()

cross_tab_percentage

# %% [markdown]
# ### Anova test - Gender

# %%
# Step 1: Prepare the data
groups = df_survey_cleaned.groupby('Gender_eng')['BI'].apply(list)

# Step 2: Perform one-way ANOVA
f_statistic, p_value = stats.f_oneway(*groups)

# Step 3: Print the results
print(f"F-statistic: {f_statistic}")
print(f"p-value: {p_value}")

# Step 4: Interpret the results
alpha = 0.05
if p_value < alpha:
    print("Reject the null hypothesis. There are significant differences between Genders.")
else:
    print("Fail to reject the null hypothesis. There are no significant differences between Genders.")

# Step 5: Visualize the data
plt.figure(figsize=(10, 6))
sns.boxplot(x='Gender_eng', y='BI', data=df_survey_cleaned)
plt.title('Distribution of BI across Genders')
plt.xlabel('Gender')
plt.ylabel('Behavioral Intention (BI)')
plt.show()

# Step 6: Post-hoc analysis (if ANOVA is significant)
if p_value < alpha:
    from statsmodels.stats.multicomp import pairwise_tukeyhsd
    tukey_results = pairwise_tukeyhsd(df_survey_cleaned['BI'], df_survey_cleaned['Gender_eng'])
    print("\nTukey HSD Results:")
    print(tukey_results)

    # Visualize Tukey HSD results
    plt.figure(figsize=(12, 6))
    tukey_results.plot_simultaneous()
    plt.title('Tukey HSD Results')
    plt.show()

# Step 7: Effect size calculation (Eta-squared)
groups_mean = df_survey_cleaned.groupby('Gender_eng')['BI'].mean()
grand_mean = df_survey_cleaned['BI'].mean()
n = len(df_survey_cleaned)
k = len(groups)

ss_between = sum(len(group) * (mean - grand_mean)**2 for group, mean in groups_mean.items())
ss_total = sum((x - grand_mean)**2 for x in df_survey_cleaned['BI'])

eta_squared = ss_between / ss_total
print(f"\nEta-squared: {eta_squared}")

# Interpret effect size
if eta_squared < 0.01:
    print("Small effect size")
elif eta_squared < 0.06:
    print("Medium effect size")
else:
    print("Large effect size")

# %% [markdown]
# ### Anova test AGE

# %%
### Conduct Anova Test of BI and AGe
# Step 1: Prepare the data
groups = df_survey_cleaned.groupby('AGE_eng')['BI'].apply(list)

# Step 2: Perform one-way ANOVA
f_statistic, p_value = stats.f_oneway(*groups)

# Step 3: Print the results
print(f"F-statistic: {f_statistic}")
print(f"p-value: {p_value}")

# Step 4: Interpret the results
alpha = 0.05
if p_value < alpha:
    print("Reject the null hypothesis. There are significant differences between age cohorts.")
else:
    print("Fail to reject the null hypothesis. There are no significant differences between age cohorts.")

# Step 5: Visualize the data
plt.figure(figsize=(10, 6))
sns.boxplot(x='AGE_eng', y='BI', data=df_survey_cleaned)
plt.title('Distribution of BI across Age Cohorts')
plt.xlabel('Age_eng')
plt.ylabel('Behavioral Intention (BI)')
plt.show()

# Step 6: Post-hoc analysis (if ANOVA is significant)
if p_value < alpha:
    from statsmodels.stats.multicomp import pairwise_tukeyhsd
    tukey_results = pairwise_tukeyhsd(df_survey_cleaned['BI'], df_survey_cleaned['AGE_eng'])
    print("\nTukey HSD Results:")
    print(tukey_results)

    # Visualize Tukey HSD results
    plt.figure(figsize=(12, 6))
    tukey_results.plot_simultaneous()
    plt.title('Tukey HSD Results')
    plt.show()

# Step 7: Effect size calculation (Eta-squared)
groups_mean = df_survey_cleaned.groupby('AGE_eng')['BI'].mean()
grand_mean = df_survey_cleaned['BI'].mean()
n = len(df_survey_cleaned)
k = len(groups)

ss_between = sum(len(group) * (mean - grand_mean)**2 for group, mean in groups_mean.items())
ss_total = sum((x - grand_mean)**2 for x in df_survey_cleaned['BI'])

eta_squared = ss_between / ss_total
print(f"\nEta-squared: {eta_squared}")

# Interpret effect size
if eta_squared < 0.01:
    print("Small effect size")
elif eta_squared < 0.06:
    print("Medium effect size")
else:
    print("Large effect size")

# %% [raw]
# Eta-squared value:
# The eta-squared value is 0.006267180527545978, which is approximately 0.0063 or 0.63%.
# Effect size interpretation:
# The output states "Small effect size", which is correct based on common guidelines for interpreting eta-squared:
# Small effect: η² < 0.01 (1%)
# Medium effect: 0.01 ≤ η² < 0.06 (1% to 6%)
# Large effect: η² ≥ 0.06 (6% or more)
# Interpretation:
# The eta-squared value of 0.0063 indicates that approximately 0.63% of the variance in the dependent variable (likely Behavioral Intention or BI) can be explained by the differences between age cohorts.
# This is considered a small effect size, meaning that while there may be some differences between age cohorts in terms of their Behavioral Intention, these differences are not substantial.
# The small effect size suggests that age cohorts alone do not account for much of the variation in Behavioral Intention. Other factors not considered in this analysis likely have a more significant impact on BI.In summary, while there are statistically significant differences in Behavioral Intention across age cohorts, the effect of age on BI is small. This suggests that age alone is not a strong predictor or influencer of Behavioral Intention in this context. Other factors not included in this analysis likely play a more important role in determining BI.

# %% [markdown]
# ### Chi^2 Tests

# %%
import pandas as pd
import numpy as np
from scipy.stats import chi2_contingency
import matplotlib.pyplot as plt
import seaborn as sns

 
# Function to perform and report Chi-square test
def chi_square_test(var1, var2, df):
    contingency_table = pd.crosstab(df[var1], df[var2])
    chi2, p_value, dof, expected = chi2_contingency(contingency_table)
    
    print(f"Chi-square test results for {var1} and {var2}:")
    print(f"Chi-square statistic: {chi2}")
    print(f"p-value: {p_value}")
    print(f"Degrees of freedom: {dof}")
    
    # Interpret the results
    alpha = 0.05
    if p_value < alpha:
        print(f"Reject the null hypothesis. There is a significant association between {var1} and {var2}.")
    else:
        print(f"Fail to reject the null hypothesis. There is no significant association between {var1} and {var2}.")
    
    # Calculate Cramer's V for effect size
    n = contingency_table.sum().sum()
    min_dim = min(contingency_table.shape) - 1
    cramer_v = np.sqrt(chi2 / (n * min_dim))
    print(f"Cramer's V: {cramer_v}")
    
    # Interpret Cramer's V
    if cramer_v < 0.1:
        print("Negligible association")
    elif cramer_v < 0.3:
        print("Weak association")
    elif cramer_v < 0.5:
        print("Moderate association")
    else:
        print("Strong association")
    
    print("\nContingency Table:")
    print(contingency_table)
    print("\nExpected Frequencies:")
    print(pd.DataFrame(expected, index=contingency_table.index, columns=contingency_table.columns))
    
    # Visualize the contingency table
    plt.figure(figsize=(10, 6))
    sns.heatmap(contingency_table, annot=True, fmt='d', cmap='YlGnBu')
    plt.title(f'Contingency Table: {var1} vs {var2}')
    plt.show()

# Perform Chi-square test for AGE_cohort and Gender
chi_square_test('AGE_eng', 'Gender', df)





# Additional analysis: Stacked bar plot for AGE_cohort and Gender
plt.figure(figsize=(12, 6))
df_percentage = df.groupby('AGE_eng')['Gender_eng'].value_counts(normalize=True).unstack()
df_percentage.plot(kind='bar', stacked=True)
plt.title('Gender Distribution Across Age Cohorts')
plt.xlabel('Age Cohort')
plt.ylabel('Percentage')
plt.legend(title='Gender')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Outliers

# %%
# Calculate Z-scores
z_scores = np.abs(stats.zscore(df['BI']))

# Identify outliers
outliers = np.where(z_scores > 3)
print("Outliers detected at indices:", outliers)

# %%
Q1 = df['BI'].quantile(0.25)
Q3 = df['BI'].quantile(0.75)
IQR = Q3 - Q1

# Identify outliers
outliers = df[(df['BI'] < (Q1 - 1.5 * IQR)) | (df['BI'] > (Q3 + 1.5 * IQR))]
#print("Outliers detected:\n", outliers)
outliers['BI']

# %%
Q1 = df['BI'].quantile(0.25)
Q3 = df['BI'].quantile(0.75)
IQR = Q3 - Q1

# Identify outliers
outliers = df[(df['BI'] < (Q1 - 1.5 * IQR)) | (df['BI'] > (Q3 + 1.5 * IQR))]
#print("Outliers detected:\n", outliers)
outliers['BI']

# %%
from sklearn.ensemble import IsolationForest
import pandas as pd


# Fit the model
iso_forest = IsolationForest(contamination=0.05, random_state=42)
df_survey_cleaned['anomaly'] = iso_forest.fit_predict(df_survey_cleaned[['BI']])

# Identify outliers
outlier_mask = df_survey_cleaned['anomaly'] == -1
outliers = df_survey_cleaned[outlier_mask]

# Get the index of outliers
outlier_indices = df_survey_cleaned.index[outlier_mask]

print("Indices of outliers:")
print(outlier_indices)

#print("\nOutlier rows:")
#print(outliers)

#print("\nBI values of outliers:")
#print(outliers['BI'])

# Drop these outliers from my DataFrame
#df_cleaned = df_survey_cleaned[~outlier_mask].drop('anomaly', axis=1)

print(f"\nOriginal DataFrame shape: {df_survey_cleaned.shape}")
print(f"Cleaned DataFrame shape: {df_survey_cleaned.shape}")

# If you want to save the cleaned DataFrame:
# df_cleaned.to_csv('cleaned_survey_data.csv', index=False)

# %% [markdown]
# ##

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats


df = df_survey_cleaned

variables = ['PE_centered', 'PU_centered', 'PEOU_centered', 'SEI_centered', 'SOI_centered', 'HM_centered', 'AT_centered', 'PPV_centered', 'BI']

# Visualization: Box Plots
plt.figure(figsize=(20, 15))  # Increased figure size
for i, var in enumerate(variables, 1):
    plt.subplot(3, 3, i)  # Changed to 3x3 grid
    sns.boxplot(x=df[var])
    plt.title(f'Box Plot for {var}')
plt.tight_layout()
plt.show()

# Initialize counters for outliers
z_outlier_count = 0
iqr_outlier_count = 0

# Statistical Method: Z-Score
outliers_zscore = {}
for var in variables:
    z_scores = np.abs(stats.zscore(df[var]))
    outliers = np.where(z_scores > 3)
    outliers_zscore[var] = outliers[0]
    z_outlier_count += len(outliers[0])
    print(f"Outliers detected in {var} using Z-score method at indices: {outliers[0]}")

# Statistical Method: IQR
outliers_iqr = {}
for var in variables:
    Q1 = df[var].quantile(0.25)
    Q3 = df[var].quantile(0.75)
    IQR = Q3 - Q1
    outliers = df[(df[var] < (Q1 - 1.5 * IQR)) | (df[var] > (Q3 + 1.5 * IQR))].index
    outliers_iqr[var] = outliers
    iqr_outlier_count += len(outliers)
    print(f"Outliers detected in {var} using IQR method at indices: {outliers.tolist()}")

# Summary of Outliers
# Combine results from both methods
combined_outliers = {}
for var in variables:
    combined_outliers[var] = {
        'Z-score': outliers_zscore[var],
        'IQR': outliers_iqr[var].tolist()
    }

# Print combined results
for var, outliers in combined_outliers.items():
    print(f"\nOutliers for {var}:")
    print(f"Z-score method: {outliers['Z-score']}")
    print(f"IQR method: {outliers['IQR']}")

# Print total count of outliers detected
print(f"\nTotal number of outliers detected using Z-score method: {z_outlier_count}")
print(f"Total number of outliers detected using IQR method: {iqr_outlier_count}")

# %%
indices_to_display = [5, 34, 67,405]
columns_of_interest = ['PE', 'PU', 'PEOU', 'SEI', 'SOI', 'HM', 'AT', 'PPV', 'BI']
print("\nDisplaying only columns of interest:")
print(df_survey_cleaned.loc[indices_to_display, columns_of_interest])

# %%
df_extr = df_survey_cleaned[['BI','PU','PEOU','SEI','SOI','PPV', 'AT','PU_centered','PEOU_centered','SEI_centered','SOI_centered']]

df_extr[(df_extr['BI'] == 1) &(df_extr['PU'] == 1) &(df_extr['PEOU'] == 1) & (df_extr['AT'] == 1)]

# %%
df_survey_cleaned['drop_column'] = np.where(
    (df_survey_cleaned['BI'] == 1) & 
    (df_survey_cleaned['PU'] == 1) & 
    (df_survey_cleaned['PEOU'] == 1) & 
    (df_survey_cleaned['AT'] == 1) ,
    'Y',
    'N'
)

df_survey_cleaned['drop_column'].value_counts()

# %% [markdown]
# ### Create Correlation Matrix of all Features

# %%
 
features =  ['BI','PU_centered', 'PEOU_centered', 'PE_centered', 'HM_centered', 'SOI_centered', 'SEI_centered', 'PPV_centered',
    'PEAT_centered', 'HMAT_centered', 'HMPU_centered', 'HMPEOU_centered', 'HMSOI_centered', 'HMSEI_centered', 'HMPE_centered',
    'AGEGender_centered', 'GenderPU_centered', 'GenderPEOU_centered', 'GenderAT_centered', 'GenderPPV_centered',
    'GenderPE_centered', 'GenderHM_centered', 'GenderSOI_centered', 'GenderSEI_centered', 'AGEPEOU_centered', 'AGEPU_centered',
    'AGESOI_centered', 'AGESEI_centered', 'AGEPPV_centered', 'AGEHM_centered', 'AGEPE_centered', 'AGEAT_centered',
    'PE_centered_cubed', 'SOI_centered_squared', 'SOI_centered_cubed', 'SEI_centered_squared', 'SEI_centered_cubed',
    'HM_centered_squared', 'HM_centered_cubed', 'AT_centered_squared', 'AT_centered_cubed', 'PPV_centered_squared', 
    'PPV_centered_cubed', 'PU_centered_squared', 'PU_centered_cubed', 'PEOU_centered_squared', 'PEOU_centered_cubed',
    'AGEGender_centered_squared', 'AGEGender_centered_cubed', 'GenderPU_centered_squared', 'GenderPU_centered_cubed',
    'GenderPEOU_centered_squared', 'GenderPEOU_centered_cubed', 'GenderAT_centered_squared', 'GenderAT_centered_cubed',
    'GenderPPV_centered_squared', 'GenderPPV_centered_cubed', 'GenderPE_centered_squared', 'GenderPE_centered_cubed',
    'GenderHM_centered_squared', 'GenderHM_centered_cubed', 'GenderSOI_centered_squared', 'GenderSOI_centered_cubed',
    'GenderSEI_centered_squared', 'GenderSEI_centered_cubed', 'AGEPEOU_centered_squared', 'AGEPEOU_centered_cubed',
    'AGEPU_centered_squared', 'AGEPU_centered_cubed', 'AGESOI_centered_squared', 'AGESOI_centered_cubed',
    'AGESEI_centered_squared', 'AGESEI_centered_cubed', 'AGEPPV_centered_squared', 'AGEPPV_centered_cubed',
    'AGEHM_centered_squared', 'AGEHM_centered_cubed', 
    'PEAT_centered_squared', 'PEAT_centered_cubed', 'HMAT_centered_squared', 'HMAT_centered_cubed', 'HMPU_centered_squared',
    'HMPU_centered_cubed', 'HMPEOU_centered_squared', 'HMPEOU_centered_cubed', 'HMSOI_centered_squared',
    'HMSOI_centered_cubed', 'HMSEI_centered_squared', 'HMSEI_centered_cubed', 'HMPE_centered_squared', 'HMPE_centered_cubed'
]
# Create a correlation matrix
corr_matrix = df_survey_cleaned[features].corr(method='spearman')

# %%
corr_matrix

# %% [markdown]
# ### Multicollinearity check

# %% [markdown]
# ### VIF with the original Survey variables

# %%
X = df_survey_cleaned[['PU1','PU2','PU3','PEOU1','PEOU2','PEOU3','AT1','AT2','AT3','PE1','PE2','PE3','HM1', 'HM2','HM3','SOI1',
       'SOI2','SOI3', 'SEI1', 'SEI2', 'SEI3', 'PPV1','PPV2','PPV3','AGE_num','Gender_num']]
def calculate_vif(X):
    vif = pd.DataFrame()
    vif["variables"] = X.columns
    vif["VIF"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
    return vif

print(calculate_vif(X))

# %% [raw]
# This Variance Inflation Factor (VIF) analysis reveals severe multicollinearity issues in the model.
# Severity of Multicollinearity:
# Almost all variables have VIF values well above 10, which is considered the threshold for severe multicollinearity.
# The highest VIF is 69.68 (HM1), and the lowest among the main variables is 39.93 (SOI3), both far exceeding acceptable levels.
# Interpretation of VIF Values:
# VIF values indicate how much the variance of a coefficient estimate is inflated due to multicollinearity.
# For example, the VIF of 69.68 for HM1 means its variance is inflated by 6968% compared to if there was no multicollinearity.
# Impact on Model:
# Such high VIFs suggest that the standard errors of the coefficients are greatly inflated, making the estimates unreliable.
# This multicollinearity can lead to unstable and unreliable coefficient estimates, reduced statistical power, and difficulty in determining individual effects of predictors.
# Exceptions:
# AGE_num (VIF = 7.34) and Gender_num (VIF = 4.17) show lower levels of multicollinearity, but are still above the ideal threshold of 1-5.
# Grouping of Variables:
# Variables seem to be grouped (e.g., PU1, PU2, PU3), suggesting they might be measuring similar constructs, which could explain the high multicollinearity.
# Potential Issues:
# The high multicollinearity may lead to difficulties in interpreting individual variable effects and could make the model unstable when applied to new data.
# Recommendations:
#
# Centering Variables: For interaction terms, center the continuous variables before creating interactions to reduce multicollinearity.

# %% [markdown]
# ### VIF for Composite Features

# %%
X = df_survey_cleaned[['PE', 'SOI', 'SEI', 'HM', 'AT', 'PPV', 'PU', 'AGE_num','Gender_num',
       'PEOU']]
def calculate_vif(X):
    vif = pd.DataFrame()
    vif["variables"] = X.columns
    vif["VIF"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
    return vif

print(calculate_vif(X))

# %% [raw]
# Evaluate the Variance Inflation Factor (VIF) results for these variables:
#
# 1. Interpretation of VIF values:
#    - VIF = 1: No correlation
#    - 1 < VIF < 5: Moderate correlation
#    - 5 ≤ VIF < 10: High correlation
#    - VIF ≥ 10: Very high correlation
#
# 2. Analysis of the results:
#
#    a) Extremely High Multicollinearity:
#       - PU (Perceived Usefulness): 126.41
#       - PPV (Price Value): 113.13
#       - AT (Attitude): 97.73
#       - SOI (Social Internal Influence): 95.27
#       - HM (Hedonic Motivation): 90.09
#       - SEI (Social External Influence): 83.70
#       - PEOU (Perceived Ease of Use): 68.33
#       - PE (Performance Expectancy): 58.48
#
#    b) High Multicollinearity:
#       - AGE_num: 6.99
#
#    c) Moderate Multicollinearity:
#       - Gender_num: 3.88
#
# 3. Implications:
#
#    a) Severe Multicollinearity Issues:
#       - Most variables (8 out of 10) have VIF values well above 10, indicating severe multicollinearity.
#       - This suggests that these variables are highly correlated with each other.
#
#    b) Potential Problems:
#       - Unstable and unreliable coefficient estimates
#       - Difficulty in determining the individual importance of variables
#       - Increased risk of overfitting
#       - Reduced predictive power of the model
#
#    c) Relatively Less Problematic Variables:
#       - AGE_num and Gender_num have lower VIF values, suggesting they are less correlated with other variables.
#
# 4. Recommendations:
#
#    a) Feature Selection:
#       - Consider removing some of the highly correlated variables.
#       - Start with the variables having the highest VIF values (e.g., PU, PPV, AT).
#
#    b) Feature Engineering:
#       - Create composite variables that combine information from highly correlated features.
#       - For example, you might create a single "Social Influence" variable combining SOI and SEI.
#
#    c) Regularization:
#       - Use regularization techniques like Lasso or Ridge regression, which can handle multicollinearity better than standard linear regression.
#
#    d) Principal Component Analysis (PCA):
#       - Consider using PCA to create uncorrelated principal components from my original features.
#
#    e) Theoretical Considerations:
#       - Consult domain experts to understand which variables are theoretically most important to keep in the model.
#
#    f) Stepwise Regression:
#       - Use stepwise regression techniques to systematically include or exclude variables based on their contribution to the model.
#
#    g) Non-linear Models:
#       - Consider using non-linear models (e.g., Random Forests, Gradient Boosting) that are less affected by multicollinearity.
#
#    h) Interaction Terms:
#       - Instead of removing variables, consider creating interaction terms between highly correlated variables.
#
#    i) Centering and Scaling:
#       - Ensure all variables are centered and scaled, which can sometimes help reduce multicollinearity issues.
#
#    j) Tolerance Analysis:
#       - Calculate tolerance (1/VIF) for each variable to get another perspective on the multicollinearity issue.
#
# 5. Caution:
#    - Be careful not to remove variables solely based on VIF values if they are theoretically important to my model.
#    - Always balance statistical considerations with domain knowledge.
#
# In conclusion, my model is suffering from severe multicollinearity issues. This explains why linear models (like Linear Regression) performed well in my previous analysis – they're essentially capturing similar information multiple times. Addressing these multicollinearity issues should be a priority before proceeding with further modeling efforts, as it will likely improve the stability and interpretability of my models.

# %% [markdown]
# ### VIF for   Interaction Features

# %%
X = df_survey_cleaned[['PU_centered', 'PEOU_centered', 'PE_centered', 'HM_centered', 'SOI_centered', 'SEI_centered', 'PPV_centered',
    'PEAT_centered', 'HMAT_centered', 'HMPU_centered', 'HMPEOU_centered', 'HMSOI_centered', 'HMSEI_centered', 'HMPE_centered',
    'AGEGender_centered', 'GenderPU_centered', 'GenderPEOU_centered', 'GenderAT_centered', 'GenderPPV_centered',
    'GenderPE_centered', 'GenderHM_centered', 'GenderSOI_centered', 'GenderSEI_centered', 'AGEPEOU_centered', 'AGEPU_centered',
    'AGESOI_centered', 'AGESEI_centered', 'AGEPPV_centered', 'AGEHM_centered', 'AGEPE_centered', 'AGEAT_centered', 'AGE_num', 'Gender_num']]


def calculate_vif(X):
    vif = pd.DataFrame()
    vif["variables"] = X.columns
    vif["VIF"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
    return vif

print(calculate_vif(X))

# %% [raw]
# This table presents Variance Inflation Factor (VIF) values for a set of variables in a statistical model. VIF is used to detect multicollinearity in regression analysis. Let's evaluate these results:
#
# ## Interpretation of VIF Values
#
# Generally, VIF values are interpreted as follows:
# - VIF = 1: No correlation
# - 1 < VIF < 5: Moderate correlation
# - 5 ≤ VIF < 10: High correlation
# - VIF ≥ 10: Very high correlation, indicating potential multicollinearity issues
#
# ## Analysis of Results
#
# 1. Severe Multicollinearity:
#    Most variables in this model show VIF values well above 10, indicating severe multicollinearity. The highest VIF values are:
#    - SOI_centered (44.92)
#    - PU_centered (43.31)
#    - AGEPU_centered (42.46)
#    - SEI_centered (41.55)
#
# 2. Moderate to High Multicollinearity:
#    Only two variables show VIF values below 10:
#    - AGE_num (7.58)
#    - Gender_num (9.07)
#
# 3. Interaction Terms:
#    Many variables appear to be interaction terms (e.g., HMPU_centered, GenderPU_centered), which often have high VIF values by design.
#
# ## Implications and Recommendations
#
# 1. Model Reliability: The high multicollinearity suggests that the model's estimates may be unreliable and difficult to interpret.
#
# 2. Predictor Redundancy: Many predictors likely contain redundant information, making it challenging to isolate their individual effects.
#
# 3. Potential Solutions:
#    - Variable Selection: Consider removing highly correlated predictors.
#    - Principal Component Analysis (PCA): Use PCA to create uncorrelated components.
#    - Ridge Regression or Lasso: These techniques can help manage multicollinearity.
#    - Centering and Scaling: Ensure all variables are centered and scaled (which appears to have been done already).
#
# 4. Caution with Interaction Terms: If many of these are interaction terms, their high VIF values might be expected. However, consider if all interactions are necessary.
#
# 5. Further Investigation: Examine the correlation matrix to identify which variables are most strongly correlated.
#
# In conclusion, this model shows severe multicollinearity issues that need to be addressed before reliable interpretations can be made. Careful variable selection and potentially alternative modeling techniques should be considered.

# %%
import pandas as pd
import numpy as np
from statsmodels.stats.outliers_influence import variance_inflation_factor

X = df_survey_cleaned[[
    'PU_centered', 'PEOU_centered', 'PE_centered', 'HM_centered', 'SOI_centered', 'SEI_centered', 'PPV_centered',
    'PEAT_centered', 'HMAT_centered', 'HMPU_centered', 'HMPEOU_centered', 'HMSOI_centered', 'HMSEI_centered', 'HMPE_centered',
    'AGEGender_centered', 'GenderPU_centered', 'GenderPEOU_centered', 'GenderAT_centered', 'GenderPPV_centered',
    'GenderPE_centered', 'GenderHM_centered', 'GenderSOI_centered', 'GenderSEI_centered', 'AGEPEOU_centered', 'AGEPU_centered',
    'AGESOI_centered', 'AGESEI_centered', 'AGEPPV_centered', 'AGEHM_centered', 'AGEPE_centered', 'AGEAT_centered',
    'PE_centered_cubed', 'SOI_centered_squared', 'SOI_centered_cubed', 'SEI_centered_squared', 'SEI_centered_cubed',
    'HM_centered_squared', 'HM_centered_cubed', 'AT_centered_squared', 'AT_centered_cubed', 'PPV_centered_squared', 
    'PPV_centered_cubed', 'PU_centered_squared', 'PU_centered_cubed', 'PEOU_centered_squared', 'PEOU_centered_cubed',
    'AGEGender_centered_squared', 'AGEGender_centered_cubed', 'GenderPU_centered_squared', 'GenderPU_centered_cubed',
    'GenderPEOU_centered_squared', 'GenderPEOU_centered_cubed', 'GenderAT_centered_squared', 'GenderAT_centered_cubed',
    'GenderPPV_centered_squared', 'GenderPPV_centered_cubed', 'GenderPE_centered_squared', 'GenderPE_centered_cubed',
    'GenderHM_centered_squared', 'GenderHM_centered_cubed', 'GenderSOI_centered_squared', 'GenderSOI_centered_cubed',
    'GenderSEI_centered_squared', 'GenderSEI_centered_cubed', 'AGEPEOU_centered_squared', 'AGEPEOU_centered_cubed',
    'AGEPU_centered_squared', 'AGEPU_centered_cubed', 'AGESOI_centered_squared', 'AGESOI_centered_cubed',
    'AGESEI_centered_squared', 'AGESEI_centered_cubed', 'AGEPPV_centered_squared', 'AGEPPV_centered_cubed',
    'AGEHM_centered_squared', 'AGEHM_centered_cubed', 
    'PEAT_centered_squared', 'PEAT_centered_cubed', 'HMAT_centered_squared', 'HMAT_centered_cubed', 'HMPU_centered_squared',
    'HMPU_centered_cubed', 'HMPEOU_centered_squared', 'HMPEOU_centered_cubed', 'HMSOI_centered_squared',
    'HMSOI_centered_cubed', 'HMSEI_centered_squared', 'HMSEI_centered_cubed', 'HMPE_centered_squared', 'HMPE_centered_cubed'
]]

def calculate_vif(X):
    vif = pd.DataFrame()
    vif["variables"] = X.columns
    vif["VIF"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
    return vif

vif_results = calculate_vif(X)
vif_results = vif_results.sort_values('VIF', ascending=False)

print("VIF Results (sorted by VIF, descending):")
print(vif_results)

print("\nVariables with VIF > 10 (potentially problematic):")
print(vif_results[vif_results['VIF'] > 10])

print("\nSummary:")
print(f"Total variables: {len(vif_results)}")
print(f"Variables with VIF > 10: {len(vif_results[vif_results['VIF'] > 10])}")
print(f"Variables with 5 < VIF <= 10: {len(vif_results[(vif_results['VIF'] > 5) & (vif_results['VIF'] <= 10)])}")
print(f"Variables with VIF <= 5: {len(vif_results[vif_results['VIF'] <= 5])}")

# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm

# Load data 
data = df_survey_cleaned[[
    'BI','PU_centered', 'PEOU_centered', 'PE_centered', 'HM_centered', 'SOI_centered', 'SEI_centered', 'PPV_centered',
    'PEAT_centered', 'HMAT_centered', 'HMPU_centered', 'HMPEOU_centered', 'HMSOI_centered', 'HMSEI_centered', 'HMPE_centered',
    'AGEGender_centered', 'GenderPU_centered', 'GenderPEOU_centered', 'GenderAT_centered', 'GenderPPV_centered',
    'GenderPE_centered', 'GenderHM_centered', 'GenderSOI_centered', 'GenderSEI_centered', 'AGEPEOU_centered', 'AGEPU_centered',
    'AGESOI_centered', 'AGESEI_centered', 'AGEPPV_centered', 'AGEHM_centered', 'AGEPE_centered', 'AGEAT_centered',
    'PE_centered_cubed', 'SOI_centered_squared', 'SOI_centered_cubed', 'SEI_centered_squared', 'SEI_centered_cubed',
    'HM_centered_squared', 'HM_centered_cubed', 'AT_centered_squared', 'AT_centered_cubed', 'PPV_centered_squared', 
    'PPV_centered_cubed', 'PU_centered_squared', 'PU_centered_cubed', 'PEOU_centered_squared', 'PEOU_centered_cubed',
    'AGEGender_centered_squared', 'AGEGender_centered_cubed', 'GenderPU_centered_squared', 'GenderPU_centered_cubed',
    'GenderPEOU_centered_squared', 'GenderPEOU_centered_cubed', 'GenderAT_centered_squared', 'GenderAT_centered_cubed',
    'GenderPPV_centered_squared', 'GenderPPV_centered_cubed', 'GenderPE_centered_squared', 'GenderPE_centered_cubed',
    'GenderHM_centered_squared', 'GenderHM_centered_cubed', 'GenderSOI_centered_squared', 'GenderSOI_centered_cubed',
    'GenderSEI_centered_squared', 'GenderSEI_centered_cubed', 'AGEPEOU_centered_squared', 'AGEPEOU_centered_cubed',
    'AGEPU_centered_squared', 'AGEPU_centered_cubed', 'AGESOI_centered_squared', 'AGESOI_centered_cubed',
    'AGESEI_centered_squared', 'AGESEI_centered_cubed', 'AGEPPV_centered_squared', 'AGEPPV_centered_cubed',
    'AGEHM_centered_squared', 'AGEHM_centered_cubed', 
    'PEAT_centered_squared', 'PEAT_centered_cubed', 'HMAT_centered_squared', 'HMAT_centered_cubed', 'HMPU_centered_squared',
    'HMPU_centered_cubed', 'HMPEOU_centered_squared', 'HMPEOU_centered_cubed', 'HMSOI_centered_squared',
    'HMSOI_centered_cubed', 'HMSEI_centered_squared', 'HMSEI_centered_cubed', 'HMPE_centered_squared', 'HMPE_centered_cubed'
]]

# Remove rows with NaN values
data = data.dropna()

# Define the dependent and independent variables
dependent_var = 'BI'
independent_vars = data.columns.drop(dependent_var).tolist()

# Fit the full model
X_full = sm.add_constant(data[independent_vars])  # Add constant for intercept
y = data[dependent_var]
full_model = sm.OLS(y, X_full).fit()
full_r_squared = full_model.rsquared

# Store the drop in R-squared for each variable
r_squared_drop = {}

# Iterate over each independent variable
for var in independent_vars:
    # Fit the model without the current variable
    X_partial = sm.add_constant(data[independent_vars].drop(var, axis=1))
    partial_model = sm.OLS(y, X_partial).fit()
    partial_r_squared = partial_model.rsquared
    
    # Calculate the drop in R-squared
    r_squared_drop[var] = full_r_squared - partial_r_squared


# Identify the variable with the largest drop in R-squared
most_influential_var = max(r_squared_drop, key=r_squared_drop.get)
largest_drop = r_squared_drop[most_influential_var]

print(f"The most influential variable is '{most_influential_var}' with a drop in R-squared of {largest_drop:.4f}.")

# Print the R-squared drops for all variables
for var, drop in sorted(r_squared_drop.items(), key=lambda x: x[1], reverse=True):
    print(f"{var}: {drop:.4f}")

# %% [raw]
# These results show the impact of each variable on the model's R-squared value when removed. This type of analysis is often used to assess variable importance. Let's evaluate these findings:
#
# ## Key Observations
#
# 1. Most Influential Variables:
#    - HMAT_centered: 0.0074 drop in R-squared
#    - SEI_centered_squared: 0.0048 drop
#    - GenderHM_centered: 0.0047 drop
#    - SEI_centered_cubed: 0.0045 drop
#    - GenderSEI_centered_cubed: 0.0035 drop
#
# 2. Least Influential Variables:
#    - Several variables show a drop of 0.0000 in R-squared, including SEI_centered, PEAT_centered_squared, AGEHM_centered_squared, etc.
#
# 3. Distribution of Impact:
#    - There's a gradual decrease in impact from the top to the bottom of the list.
#    - Many variables have very small impacts (< 0.001 drop in R-squared).
#
# 4. Presence of Squared and Cubed Terms:
#    - Many variables appear in linear, squared, and cubed forms, indicating a complex polynomial model.
#
# ## Implications and Insights
#
# 1. Model Complexity:
#    - The model includes many polynomial terms (squared and cubed), suggesting attempts to capture non-linear relationships.
#    - This complexity might contribute to the multicollinearity issues noted earlier.
#
# 2. Variable Importance:
#    - HMAT_centered (likely "Hedonic Motivation * Attitude") appears to be the most crucial predictor.
#    - Gender interactions (e.g., GenderHM_centered) seem important, indicating gender differences in the model.
#
# 3. Potential Overfitting:
#    - The presence of many variables with very small impacts suggests possible overfitting.
#    - The model might be capturing noise rather than meaningful patterns in some cases.
#
# 4. Non-linear Effects:
#    - Squared and cubed terms of some variables (e.g., SEI_centered) have significant impacts, indicating important non-linear relationships.
#
# 5. Interaction Effects:
#    - Several interaction terms (e.g., GenderHM_centered) show notable impacts, suggesting important moderating effects.
#
# ## Recommendations
#
# 1. Focus on Key Predictors:
#    - Prioritize the top 10-15 variables with the highest impact on R-squared.
#    - Consider removing or combining variables with very low impact (e.g., < 0.0001 drop in R-squared).
#
# 2. Simplify the Model:
#    - Reduce the number of polynomial terms, keeping only those that significantly improve the model.
#    - This can help address multicollinearity and potential overfitting issues.
#
# 3. Investigate Non-linear Relationships:
#    - For variables where squared or cubed terms are important, explore these non-linear relationships graphically.
#
# 4. Gender and Age Effects:
#    - Pay special attention to gender and age interactions, as they appear to be significant moderators.
#
# 5. Theoretical Consideration:
#    - Ensure that the retained variables align with theoretical expectations in my field of study.
#
# 6. Cross-validation:
#    - Use cross-validation techniques to ensure the model's performance is consistent across different subsets of the data.
#
# 7. Stepwise Approach:
#    - Consider a stepwise regression approach, starting with the most impactful variables and adding others incrementally.
#
# 8. Multicollinearity Check:
#    - Re-evaluate multicollinearity after model simplification, as removing redundant variables may improve VIF scores.
#
# In conclusion, while this analysis provides valuable insights into variable importance, it also highlights the need for model simplification. Focusing on the most impactful variables while reducing complexity can lead to a more interpretable and potentially more robust model.

# %% [raw]
# ## Features to keep so far:
#
# Final recommended list of variables to keep:
#
# 1. PEOU_centered (core construct, linear term)
# 2. PU_centered (core construct, linear term)
# 3. AT_centered (core construct, linear term)
# 4. PE_centered (core construct, linear term)
# 5. HM_centered (core construct, linear term)
# 6. SOI_centered (core construct, linear term)
# 7. SEI_centered (linear term)
# 8. PPV_centered (core construct, linear term)
# 9. AGE_num (linear term)
# 10. Gender_num (linear term)
# 11. HMAT_centered (interaction term)
# 12. GenderHM_centered (interaction term)
# 13. HMPE_centered (interaction term)
# 14. AGEPEOU_centered_squared (non-linear term)
# 15. SEI_centered_squared (non-linear term)
# 16. SOI_centered_squared (non-linear term)
# 17. GenderSEI_centered_cubed (non-linear interaction term)
# 18. HMSOI_centered_cubed (non-linear interaction term)
# 19. GenderHM_centered_cubed (non-linear interaction term)
#
# This revised list now correctly includes all the core constructs, including PPV_centered, as well as important interaction and non-linear terms.
#
# Rationale:
# - All core constructs (PEOU, PU, AT, PE, HM, SOI, PPV) are included as linear terms.
# - Key demographic factors (age and gender) are retained.
# - Important interaction and non-linear terms are kept to capture complex relationships.
#
# Recommendations for next steps:
# Multicollinearity Check: Recalculate VIF scores for this set of variables to ensure multicollinearity has been sufficiently reduced.
# Model Performance: Compare the performance of this simplified model to the original model using metrics like R-squared, adjusted R-squared, AIC, and BIC.
# Theoretical Alignment: Verify that this selection aligns well with my research questions and hypotheses.
# Interaction Analysis: Consider if any additional interactions between core constructs should be included based on my theoretical framework.
# Stepwise Refinement: Use this as a starting point and consider stepwise procedures (forward selection or backward elimination) to fine-tune the model if needed.
# Residual Analysis: After fitting the model with these variables, conduct a thorough residual analysis to ensure model assumptions are met.
# Interpretation: Carefully interpret the effects, particularly for the non-linear terms and interactions.
# Cross-validation: If possible, use cross-validation techniques to assess the model's predictive performance and stability.
#
# This final list should provide a comprehensive foundation for my model, balancing theoretical importance with statistical considerations. It includes all core constructs while still addressing the multicollinearity issues we discussed earlier.

# %% [markdown]
# ### End Exploration

# %%
print('End of Script')
